# %% [markdown]
# ## Problem set 1, Intro to NLP, 2017
#
# #### This is due on September 22nd at 11PM. Please see detailed submission instructions below.  100 points total.
#
# ##### How to do this problem set:
#
# - What version of Python should I use? 2.7
#
# - Most of these questions require writing Python code and computing results, and the rest of them have textual answers. To generate the answers, you will have to fill out a supporting file, `hw_1.py`.
#
# - For all of the textual answers you have to fill out have placeholder text which says "Answer in one or two sentences here." For each question, you need to replace "Answer in one or two sentences here" with your answer.
#
# - Write all the answers in this ipython notebook. Once you are finished (1) Generate a PDF via (File -> Download As -> PDF) and upload to Gradescope (2)Turn in `hw_1.py` and `hw_1.ipynb` on Moodle.
#
# - **Important:** Check your PDF before you turn it in to gradescope to make sure it exported correctly. If ipyhton notebook gets confused about your syntax it will sometimes terminate the PDF creation routine early. You are responsible for checking for these errors. If your whole PDF does not print, try running `$jupyter nbconvert --to pdf hw_1.ipynb` to identify and fix any syntax errors that might be causing problems.
#
# - **Important:** When creating your final version of the PDF to hand in, please do a fresh restart and execute every cell in order. Then you'll be sure it's actually right. One convenient way to do this is by clicking `Cell -> Run All` in the notebook menu.
#
# - This assignment is designed so that you can run all cells in a few minutes of computation time. If it is taking longer than that, you probably have made a mistake in your code.

# %% [markdown]
# ##### Academic honesty
#
# - We will audit the Moodle code from a few dozen students, chosen at random. The audits will check that the code you wrote and turned on Moodle generates the answers you turn in on your Gradescope PDF. If you turn in correct answers on your PDF without code that actually generates those answers, we will consider this a potential case of cheating. See the course page for honesty policies.
#
# - We will also run automatic checks of code on Moodle for plagiarism. Copying code from others is considered a serious case of cheating.

# %%
# Run this cell! It sets some things up for you.

# This code makes plots appear inline in this document rather than in a new window.
import matplotlib.pyplot as plt
from __future__ import division  # this line is important to avoid unexpected behavior from division

# This code imports your work from hw_1.py
from hw_1 import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 4) # set default size of plots

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# download the IMDB large movie review corpus from the class webpage to a file location on your computer

PATH_TO_DATA = 'large_movie_review_dataset'  # set this variable to point to the location of the IMDB corpus on your computer
POS_LABEL = 'pos'
NEG_LABEL = 'neg'
TRAIN_DIR = os.path.join(PATH_TO_DATA, "train")
TEST_DIR = os.path.join(PATH_TO_DATA, "test")

for label in [POS_LABEL, NEG_LABEL]:
    if len(os.listdir(TRAIN_DIR + "/" + label)) == 12500:
        print "Great! You have 12500 {} reviews in {}".format(label, TRAIN_DIR + "/" + label)
    else:
        print "Oh no! Something is wrong. Check your code which loads the reviews"
# Out:
# Great! You have 12500 pos reviews in large_movie_review_dataset\train/pos
# Great! You have 12500 neg reviews in large_movie_review_dataset\train/neg

# %%
# Actually reading the data you are working with is an important part of NLP! Let's look at one of these reviews

print open(TRAIN_DIR + "/neg/3740_2.txt").read()
# Out:
# Right away, this film was ridiculous. Not that it didn't have redeeming aspects For example, the best thing about this film was the beautiful background scenery. Anyone not living on the East Coast should know the South doesn't have beautiful mountains like those found in the West. I knew it was Utah right off the bat, but perhaps Dalton couldn't suppress his English accent, so they had to excuse it by saying this was a southern town. Subverting his accent into a Southern one was easier. Sure the film has plot twists, but its phony sense of place was something I couldn't get past. It's not like Utah doesn't have meth labs... so why the writers thought it necessary to pretend it was in the South is beyond me. <br /><br />One other thing in action pictures always puzzles me. Why do they always make the "cocking" sound effect when the character pulls out an automatic handgun? It seemed every other sound effect in this movie was a "chuk-chich" signifying a 9mm was loaded and ready to fire. Of course, the weapons already had rounds chambered so this was unnecessary. <br /><br />Lastly, the pyrotechnics were WAY over the top. But hey, this film was targeted to a certain 'market segment' I suppose... It's too bad. Each of the actors can act, but this film was lame.

# %% [markdown]
# ## Part One: Intro to NLP in Python: types, tokens and Zipf's law

# %% [markdown]
# #### Types and tokens
#
# One major part of any NLP project is word tokenization. Word tokenization is the task of segmenting text into individual words, called tokens. In this assignment, we will use simple whitespace tokenization. You will have a chance to improve this for extra credit at the end of the assigment. Take a look at the `tokenize_doc` function in `hw_1.py`. **You should not modify tokenize_doc** but make sure you understand what it is doing.

# %%
# We have provided a tokenize_doc function in hw_1.py. Here is a short demo of how it works

d1 = "This SAMPLE doc has   words tHat  repeat repeat"
bow = tokenize_doc(d1)

assert bow['this'] == 1
assert bow['sample'] == 1
assert bow['doc'] == 1
assert bow['has'] == 1
assert bow['words'] == 1
assert bow['that'] == 1
assert bow['repeat'] == 2

bow2 = tokenize_doc("Computer science is both practical and abstract.")
for b in bow2:
    print b
# Out:
# and
# both
# computer
# abstract.
# science
# is
# practical

# %% [markdown]
# **Question 1.1 (5 points)**
#
# Now we are going to count the word types and word tokens in the corpus. In the cell below, use the `word_counts` dictionary variable to store the count of each word in the corpus.
# Use the `tokenize_doc` function to break documents into tokens.
#
# `word_counts` keeps track of how many times a word type appears across the corpus. For instance, `word_counts["dog"]` should store the number 990 -- the count of how many times the word `dog` appears in the corpus.

# %%
import glob
word_counts = {}  # you might want to use a defaultdict instead https://docs.python.org/2/library/collections.html
                  # defaultdicts are often useful for NLP in python
corpus = ''

for label in [POS_LABEL, NEG_LABEL]:
    for directory in [TRAIN_DIR, TEST_DIR]:
        for fn in glob.glob(directory + "/" + label + "/*txt"):
            ## Implement me!
            with open(fn, 'r') as txt:
                corpus = corpus + ' ' + txt.read()   
                
word_counts = tokenize_doc(corpus)

# %%
# you should see 990 instances of the word type "dog" in the corpus. (updated 9/13)
if word_counts["dog"] == 990:
    print "yay! there are {} total instances of the word type dog in the corpus".format(word_counts["dog"])
else:
    print "hrm. Something seems off. Double check your code"
# Out:
# yay! there are 990.0 total instances of the word type dog in the corpus

# %% [markdown]
# **Question 1.2 (5 points)**
#
# Fill out the functions `n_word_types` and `n_word_tokens` in `hw_1.py`. These functions return the total number of word types and tokens in the corpus. **important** The autoreload "magic" that you setup early in the assignment should automatically reload functions as you make changes and save. If you run into trouble you can always restart the notebook and clear any .pyc files.

# %%
print "there are {} word types in the corpus".format(n_word_types(word_counts))
print "there are {} word tokens in the corpus".format(n_word_tokens(word_counts))
# Out:
# there are 391997 word types in the corpus
# there are 11557403.0 word tokens in the corpus

# %% [markdown]
# **Question 1.3 (5 points)**
#
# You should see a much higher number of tokens than types. Why is that?
#
# A token is any word as perceived by the tokenizer, while a type is a unique word. Therefore the total number of word types is the set of the total tokens, and if there are multiple instances of specific tokens then there will be more tokens than types.

# %% [markdown]
# #### Zipf's Law
#
# **Question 1.4 (5 points)**
#
# In this section, you will verify a key statistical properties of text: [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law).
#
# Zipf's Law describes the relations between the frequency rank of words and frequency value of words.  For a word $w$, its frequency is inversely proportional to its rank:
#
# $$count_w = K \frac{1}{rank_w}$$
# or in other words
# $$\log(count_w) = K - \log(rank_w)$$
#
# for some constant $K$, specific to the corpus and how words are being defined.
#
# Therefore, if Zipf's Law holds, after sorting the words descending on frequency, word frequency decreases in an approximately linear fashion under a log-log scale.
#
# Please make such a log-log plot by ploting the rank versus frequency.  Use a scatter plot where the x-axis is the *log(rank)*, and y-axis is *log(frequency)*.  You should get this information from `word_counts`; for example, you can take the individual word counts and sort them.  dict methods `.items()` and/or `values()` may be useful.  (Note that it doesn't really matter whether ranks start at 1 or 0 in terms of how the plot comes out.) You can check your results by comparing your plots to ones on Wikipedia; they should look qualitatively similar.
#
# *Please remember to label the meaning of the x-axis and y-axis.*

# %%
import math
x = []
y = []
X_LABEL = "log(rank)"
Y_LABEL = "log(frequency)"

# implement me! you should fill the x and y arrays. Add your code here
sorted_wc = sorted(word_counts, key=word_counts.get, reverse=True)

for rank, freq in enumerate(sorted_wc):
    x.append(math.log(rank + 1))
    y.append(math.log(word_counts[sorted_wc[rank]]))

plt.scatter(x, y)
plt.xlabel(X_LABEL)
plt.ylabel(Y_LABEL)

# %% [markdown]
# **Question 1.5 (5 points)**
#
# You should see some discountinuities on the left and right sides of this figure.  Why are we seeing them on the left?  Why are we seeing them on the right?  On the right, what are those "ledges"?
#
# Answer in one or two sentences here.
#
# On the left, there are some discontinuities because the
#
# On the right, there are discontinuities because many words appear only once or twice. The ledge at 0 on the y-axis represents the words that only occur once, as log(1) = 0.

# %% [markdown]
# ## Part Two: Naive Bayes

# %% [markdown]
# This section of the homework will walk you through coding a Naive Bayes classifier that can distinguish between postive and negative reviews (at some level of accuracy).

# %% [markdown]
# **Question 2.1 (5 pts) ** To start, implement the `update_model` function in `hw_1.py`. Make sure to read the function comments so you know what to update. Also review the NaiveBayes class variables in the `def __init__` method of the NaiveBayes class  to get a sense of which statistics are important to keep track of. Once you have implemented `update_model`, run the train model function using the code below. You’ll need to provide the path to the dataset you downloaded to run the code.

# %%
nb = NaiveBayes(PATH_TO_DATA, tokenizer=tokenize_doc)
nb.train_model()

if len(nb.vocab) == 252165:
    print "Great! The vocabulary size is {}".format(252165)
else:
    print "Oh no! Something seems off. Double check your code before continuing. Maybe a mistake in update_model?"
# Out:
# REPORTING CORPUS STATISTICS
# NUMBER OF DOCUMENTS IN POSITIVE CLASS: 12500.0
# NUMBER OF DOCUMENTS IN NEGATIVE CLASS: 12500.0
# NUMBER OF TOKENS IN POSITIVE CLASS: 2958730.0
# NUMBER OF TOKENS IN NEGATIVE CLASS: 2885734.0
# VOCABULARY SIZE: NUMBER OF UNIQUE WORDTYPES IN TRAINING CORPUS: 252165
# Great! The vocabulary size is 252165

# %% [markdown]
# #### Exploratory analysis
#
# Let’s begin to explore the count statistics stored by the update model function. Use the provided `top_n` function to find the top 10 most common words in the positive class and top 10 most common words in the negative class. You don't have to code anything to do this.

# %%
print "TOP 10 WORDS FOR CLASS " + POS_LABEL + ":"
for tok, count in nb.top_n(POS_LABEL, 10):
    print '', tok, count
print ''

print "TOP 10 WORDS FOR CLASS " + NEG_LABEL + ":"
for tok, count in nb.top_n(NEG_LABEL, 10):
    print '', tok, count
print ''
# Out:
# TOP 10 WORDS FOR CLASS pos:
#  the 165803.0
#  and 87022.0
#  a 82054.0
#  of 76155.0
#  to 65869.0
#  is 55785.0
#  in 48420.0
#  i 33143.0
#  it 32795.0
#  that 32702.0
#
# TOP 10 WORDS FOR CLASS neg:
#  the 156385.0
#  a 77895.0
#  and 71534.0
#  of 68304.0
#  to 68097.0
#  is 48385.0
#  in 42103.0
#  i 37335.0
#  this 37301.0
#  that 33585.0

# %% [markdown]
# **Question 2.2 (5 points)**
#
# Will the top 10 words of the positive/negative classes help discriminate between the two classes? Do you imagine that processing other English text will result in a similar phenomenon?
#
# Answer in one or two sentences here.
#
# No. The most common words in a text are likely to be low-context words that are can appear in almost any situation such as determiners, prepositions, and complementizers; as such, these common words cannot be used to discriminate in any direction in the movie review corpus, or in any other texts.

# %% [markdown]
# **Question 2.3 (5 pts) **
#
# The Naive Bayes model assumes that all features are conditionally independent given the class label. For our purposes, this means that the probability of seeing a particular word in a document with class label $y$ is independent of the rest of the words in that document. Implement the `p_word_given_label` function. This function calculates P (w|y) (i.e., the probability of seeing word w in a document given the label of that document is y).

# %% [markdown]
# Use your `p_word_given_label` function to compute the probability of seeing the word “fantastic” given each sentiment label. Repeat the computation for the word “boring.”

# %%
print "P('fantastic'|pos):",  nb.p_word_given_label("fantastic", POS_LABEL)
print "P('fantastic'|neg):",  nb.p_word_given_label("fantastic", NEG_LABEL)
print "P('boring'|pos):",  nb.p_word_given_label("boring", POS_LABEL)
print "P('boring'|neg):",  nb.p_word_given_label("boring", NEG_LABEL)
# Out:
# P('fantastic'|pos): 0.000154458162793
# P('fantastic'|neg): 3.77720191813e-05
# P('boring'|pos): 6.18508616873e-05
# P('boring'|neg): 0.000287275265149

# %% [markdown]
# Which word has a higher probability given the positive class, fantastic or boring? Which word has a higher probability given the negative class? Is this what you would expect?
#
# Answer in one or two sentences here
#
# Given the positive class, "fantastic" is more likely to occur than "boring." Vice versa, given the negative class, "boring" is more likely to occur than "fantastic." This result is as expected.

# %% [markdown]
# **Question 2.4 (5 pts)**
#
# In the next cell, compute the probability of the word "car-thievery" in the positive training data and negative training data.

# %%
print "P('car-thievery'|pos):",  nb.p_word_given_label("car-thievery", POS_LABEL)
print "P('car-thievery'|neg):",  nb.p_word_given_label("car-thievery", NEG_LABEL)
# Out:
# P('car-thievery'|pos): 3.3798285075e-07
# P('car-thievery'|neg): 0.0

# %% [markdown]
# What do you notice about "P('car-thievery'|neg)"? Why do you see this number? What would happen if we took the log of "P('car-thievery'|neg)"? What would happen if we multiplied "P('car-thievery'|neg)" by "P('cliche'|neg)"? Why might these operations cause problems for a Naive Bayes classifier?
#
# Answer in one or two sentences here
#
# "Car-thievery" has a P of zero in the negative label because it doesn't occur in the negative training data. The log of "P('car-thievery'|neg)" would be undefined. Multiplying "P('car-thievery'|neg)" by "P('cliche'|neg)" would result in a value of zero, which would cause problems for a Naive Bayes classifier by setting probabilities to 0 when the real-world probability is not such.

# %% [markdown]
# **Question 2.5 (5 pts)**
#
# We can address the issues from question 2.4 with psuedocounts. A psuedocount is a fixed amount added to the count of each word stored in our model. Psuedocounts are used to help smooth calculations involving words for which there is little data. Implement
# `p_word_given_label_and_psuedocount` and then run the next cell. Hint: look at the slides from the lecture on pseudocounts.

# %%
print "P('car-thievery'|neg):",  nb.p_word_given_label_and_pseudocount("car-thievery", NEG_LABEL, 1.0)
# Out:
# P('car-thievery'|neg): 3.28417471153e-07

# %% [markdown]
# **Question 2.6 (getting ready for question 2.10)**
#
# *Prior and Likelihood*
#
# As noted before, the Naive Bayes model assumes that all words in a document are independent of one another given the document’s label. Because of this we can write the likelihood of a document as:
#
# $P(w_{d1},\cdots,w_{dn}|y_d) = \prod_{i=1}^{n}P(w_{di}|y_d)$
#
# However, if a document has a lot of words, the likelihood will become extremely small and we’ll encounter numerical underflow. Underflow is a common problem when dealing with prob- abilistic models; if you are unfamiliar with it, you can get a brief overview on [Wikipedia](https:/en.wikipedia.org/wiki/Arithmetic_underflow). To deal with underflow, a common transformation is to work in log-space.
#
# $\log[P(w_{d1},\cdots,w_{dn}|y_d)] = \sum_{i=1}^{n}\log[P(w_{di}|y_d)]$

# %% [markdown]
# Implement the `log_likelihood` function (Hint: it should make calls to the p word given label and psuedocount function).
# Implement the `log_prior` function. This function takes a class label and returns the log of the fraction of the training documents that are of that label.
#
# There is nothing to print out for this question. But you will use these functions in a moment...

# %% [markdown]
# **Question 2.7 (5 pts) **
#
# Naive Bayes is a model that tells us how to compute the posterior
# probability of a document being of some label (i.e.,
# $P(y_d|\mathbf{w_d})$).  Specifically, we do so using bayes rule:
#
#   $P(y_d|\mathbf{w_d}) = \frac{P(y_d)P(\mathbf{w_d}|y_d)}{P(\mathbf{w_d})}$
#
# In the previous section you implemented functions to compute both
# the log prior ($\log[P(y_d)]$) and the log likelihood
# ($\log[P( \mathbf{w_d} |y_d)]$ ). Now, all your missing is the
# *normalizer*, $P(\mathbf{w_d})$.

# %% [markdown]
# Derive the normalizer by expanding $P(\mathbf{w_d})$. You will have to use "MathJax" to write out the equations. MathJax is very similar to LaTeX. 99% of the MathJax you will need to write for this course (and others at U Mass) is included in the first answer of [this](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) tutorial. MathJax and LaTeX can be annoying first, but once you get a little practice, using these tools will feel like second nature.
#
#
# Derive the normalizer by expanding $P(\mathbf{w_d})$. Fill out the answer with MathJax here
#
# $P(\mathbf{w_d}) = \sum_{d\in\{pos, neg\}}P(y_d)P(\mathbf{w_d}|y_d)$

# %% [markdown]
# **Question 2.8 (5 pts)**
#
# One way to classify a document is to compute the unnormalized log posterior for both labels and take the argmax (i.e., the label that yields the higher unnormalized log posterior). The unnormalized log posterior is the sum of the log prior and the log likelihood of the document. Why don’t we need to compute the log normalizer here?

# %% [markdown]
# Answer in one or two sentences here.
#
# We don't need to compute the log normalizer because its value does not change for each label $y_d$ as we are trying to find the right label for $d$.

# %% [markdown]
# **Question 2.9 (15 pts)**
#
# Implement the `unnormalized_log_posterior` function and the `classify` function. The `classify` function should use the unnormalized log posteriors but should not compute the normalizer. Once you implement the `classify` function, we'd like to evaluate its accuracy. `evaluate_classifier_accuracy` is implemented for you so you don't need to change that method.

# %%
print nb.evaluate_classifier_accuracy(1.0)
# Out:
# large_movie_review_dataset\test\pos/10009_10.txt
# large_movie_review_dataset\test\pos/10012_9.txt
# large_movie_review_dataset\test\pos/10017_8.txt
# large_movie_review_dataset\test\pos/10018_8.txt
# large_movie_review_dataset\test\pos/10023_8.txt
# large_movie_review_dataset\test\pos/10024_9.txt
# large_movie_review_dataset\test\pos/10038_7.txt
# large_movie_review_dataset\test\pos/10055_10.txt
# large_movie_review_dataset\test\pos/10057_8.txt
# large_movie_review_dataset\test\pos/10059_10.txt
# large_movie_review_dataset\test\pos/1005_7.txt
# large_movie_review_dataset\test\pos/10060_10.txt
# large_movie_review_dataset\test\pos/10062_9.txt
# large_movie_review_dataset\test\pos/10069_10.txt
# large_movie_review_dataset\test\pos/1006_8.txt
# large_movie_review_dataset\test\pos/10073_7.txt
# large_movie_review_dataset\test\pos/10076_10.txt
# large_movie_review_dataset\test\pos/10078_10.txt
# large_movie_review_dataset\test\pos/10081_10.txt
# large_movie_review_dataset\test\pos/10082_8.txt
# large_movie_review_dataset\test\pos/10085_10.txt
# large_movie_review_dataset\test\pos/10086_10.txt
# large_movie_review_dataset\test\pos/10088_8.txt
# large_movie_review_dataset\test\pos/1008_10.txt
# large_movie_review_dataset\test\pos/10091_10.txt
# large_movie_review_dataset\test\pos/10092_8.txt
# large_movie_review_dataset\test\pos/10095_9.txt
# large_movie_review_dataset\test\pos/10099_9.txt
# large_movie_review_dataset\test\pos/10105_8.txt
# large_movie_review_dataset\test\pos/10106_10.txt
# large_movie_review_dataset\test\pos/10127_10.txt
# large_movie_review_dataset\test\pos/1012_8.txt
# large_movie_review_dataset\test\pos/10139_10.txt
# large_movie_review_dataset\test\pos/1014_8.txt
# large_movie_review_dataset\test\pos/10155_7.txt
# large_movie_review_dataset\test\pos/1016_7.txt
# large_movie_review_dataset\test\pos/10174_9.txt
# large_movie_review_dataset\test\pos/10179_10.txt
# large_movie_review_dataset\test\pos/10188_10.txt
# large_movie_review_dataset\test\pos/10190_10.txt
# large_movie_review_dataset\test\pos/10194_7.txt
# large_movie_review_dataset\test\pos/10195_10.txt
# large_movie_review_dataset\test\pos/10197_8.txt
# large_movie_review_dataset\test\pos/101_9.txt
# large_movie_review_dataset\test\pos/1020_7.txt
# large_movie_review_dataset\test\pos/10213_7.txt
# large_movie_review_dataset\test\pos/10217_7.txt
# large_movie_review_dataset\test\pos/10219_9.txt
# large_movie_review_dataset\test\pos/1021_7.txt
# large_movie_review_dataset\test\pos/10224_9.txt
# large_movie_review_dataset\test\pos/10227_7.txt
# large_movie_review_dataset\test\pos/10228_10.txt
# large_movie_review_dataset\test\pos/10233_7.txt
# large_movie_review_dataset\test\pos/10235_10.txt
# large_movie_review_dataset\test\pos/10236_10.txt
# large_movie_review_dataset\test\pos/1023_10.txt
# large_movie_review_dataset\test\pos/10248_9.txt
# large_movie_review_dataset\test\pos/10252_10.txt
# large_movie_review_dataset\test\pos/10259_10.txt
# large_movie_review_dataset\test\pos/10264_8.txt
# large_movie_review_dataset\test\pos/10274_8.txt
# large_movie_review_dataset\test\pos/10276_8.txt
# large_movie_review_dataset\test\pos/10286_10.txt
# large_movie_review_dataset\test\pos/102_8.txt
# large_movie_review_dataset\test\pos/10300_10.txt
# large_movie_review_dataset\test\pos/10319_8.txt
# large_movie_review_dataset\test\pos/10330_9.txt
# large_movie_review_dataset\test\pos/10333_10.txt
# large_movie_review_dataset\test\pos/10340_7.txt
# large_movie_review_dataset\test\pos/10353_10.txt
# large_movie_review_dataset\test\pos/10354_7.txt
# large_movie_review_dataset\test\pos/10355_10.txt
# large_movie_review_dataset\test\pos/10356_7.txt
# large_movie_review_dataset\test\pos/10357_7.txt
# large_movie_review_dataset\test\pos/10362_7.txt
# large_movie_review_dataset\test\pos/10366_8.txt
# large_movie_review_dataset\test\pos/10376_10.txt
# large_movie_review_dataset\test\pos/10377_8.txt
# large_movie_review_dataset\test\pos/10382_10.txt
# large_movie_review_dataset\test\pos/10391_9.txt
# large_movie_review_dataset\test\pos/10393_9.txt
# large_movie_review_dataset\test\pos/10395_10.txt
# large_movie_review_dataset\test\pos/10400_9.txt
# large_movie_review_dataset\test\pos/10402_8.txt
# large_movie_review_dataset\test\pos/10403_10.txt
# large_movie_review_dataset\test\pos/10404_9.txt
# large_movie_review_dataset\test\pos/10406_8.txt
# large_movie_review_dataset\test\pos/10407_10.txt
# large_movie_review_dataset\test\pos/10410_10.txt
# large_movie_review_dataset\test\pos/10413_8.txt
# large_movie_review_dataset\test\pos/10422_9.txt
# large_movie_review_dataset\test\pos/10425_10.txt
# large_movie_review_dataset\test\pos/10426_8.txt
# large_movie_review_dataset\test\pos/10435_7.txt
# large_movie_review_dataset\test\pos/10438_9.txt
# large_movie_review_dataset\test\pos/10440_7.txt
# large_movie_review_dataset\test\pos/10443_7.txt
# large_movie_review_dataset\test\pos/10447_7.txt
# large_movie_review_dataset\test\pos/10448_7.txt
# large_movie_review_dataset\test\pos/10454_8.txt
# large_movie_review_dataset\test\pos/10455_9.txt
# large_movie_review_dataset\test\pos/10456_10.txt
# large_movie_review_dataset\test\pos/10458_7.txt
# large_movie_review_dataset\test\pos/10494_8.txt
# large_movie_review_dataset\test\pos/10497_10.txt
# large_movie_review_dataset\test\pos/10498_10.txt
# large_movie_review_dataset\test\pos/10499_8.txt
# large_movie_review_dataset\test\pos/10500_7.txt
# large_movie_review_dataset\test\pos/10501_10.txt
# large_movie_review_dataset\test\pos/10502_7.txt
# large_movie_review_dataset\test\pos/10503_8.txt
# large_movie_review_dataset\test\pos/10504_7.txt
# large_movie_review_dataset\test\pos/10507_7.txt
# large_movie_review_dataset\test\pos/10509_8.txt
# large_movie_review_dataset\test\pos/10510_7.txt
# large_movie_review_dataset\test\pos/10513_7.txt
# large_movie_review_dataset\test\pos/10519_8.txt
# large_movie_review_dataset\test\pos/10523_9.txt
# large_movie_review_dataset\test\pos/10533_10.txt
# large_movie_review_dataset\test\pos/10538_10.txt
# large_movie_review_dataset\test\pos/10539_8.txt
# large_movie_review_dataset\test\pos/10540_10.txt
# large_movie_review_dataset\test\pos/10541_8.txt
# large_movie_review_dataset\test\pos/10542_10.txt
# large_movie_review_dataset\test\pos/10543_7.txt
# large_movie_review_dataset\test\pos/10544_10.txt
# large_movie_review_dataset\test\pos/10545_10.txt
# large_movie_review_dataset\test\pos/10550_8.txt
# large_movie_review_dataset\test\pos/10551_10.txt
# large_movie_review_dataset\test\pos/10552_7.txt
# large_movie_review_dataset\test\pos/10563_9.txt
# large_movie_review_dataset\test\pos/10569_7.txt
# large_movie_review_dataset\test\pos/10581_10.txt
# large_movie_review_dataset\test\pos/10582_10.txt
# large_movie_review_dataset\test\pos/10584_8.txt
# large_movie_review_dataset\test\pos/10585_8.txt
# large_movie_review_dataset\test\pos/10587_10.txt
# large_movie_review_dataset\test\pos/10589_10.txt
# large_movie_review_dataset\test\pos/10590_9.txt
# large_movie_review_dataset\test\pos/10592_8.txt
# large_movie_review_dataset\test\pos/10593_8.txt
# large_movie_review_dataset\test\pos/10594_10.txt
# large_movie_review_dataset\test\pos/10597_10.txt
# large_movie_review_dataset\test\pos/10599_8.txt
# large_movie_review_dataset\test\pos/10600_10.txt
# large_movie_review_dataset\test\pos/10602_8.txt
# large_movie_review_dataset\test\pos/10603_8.txt
# large_movie_review_dataset\test\pos/10604_8.txt
# large_movie_review_dataset\test\pos/10606_10.txt
# large_movie_review_dataset\test\pos/10620_9.txt
# large_movie_review_dataset\test\pos/10630_7.txt
# large_movie_review_dataset\test\pos/10639_10.txt
# large_movie_review_dataset\test\pos/10643_9.txt
# large_movie_review_dataset\test\pos/10645_10.txt
# large_movie_review_dataset\test\pos/10670_9.txt
# large_movie_review_dataset\test\pos/10671_9.txt
# large_movie_review_dataset\test\pos/10675_8.txt
# large_movie_review_dataset\test\pos/10676_8.txt
# large_movie_review_dataset\test\pos/10677_10.txt
# large_movie_review_dataset\test\pos/10679_8.txt
# large_movie_review_dataset\test\pos/10680_7.txt
# large_movie_review_dataset\test\pos/10681_8.txt
# large_movie_review_dataset\test\pos/10685_7.txt
# large_movie_review_dataset\test\pos/10689_10.txt
# large_movie_review_dataset\test\pos/10692_10.txt
# large_movie_review_dataset\test\pos/10693_10.txt
# large_movie_review_dataset\test\pos/10695_10.txt
# large_movie_review_dataset\test\pos/10696_10.txt
# large_movie_review_dataset\test\pos/10700_10.txt
# large_movie_review_dataset\test\pos/10701_10.txt
# large_movie_review_dataset\test\pos/10703_9.txt
# large_movie_review_dataset\test\pos/10749_8.txt
# large_movie_review_dataset\test\pos/10761_8.txt
# large_movie_review_dataset\test\pos/10766_8.txt
# large_movie_review_dataset\test\pos/10769_7.txt
# large_movie_review_dataset\test\pos/10771_8.txt
# large_movie_review_dataset\test\pos/10783_7.txt
# large_movie_review_dataset\test\pos/10787_10.txt
# large_movie_review_dataset\test\pos/10789_8.txt
# large_movie_review_dataset\test\pos/10791_9.txt
# large_movie_review_dataset\test\pos/10795_10.txt
# large_movie_review_dataset\test\pos/10802_8.txt
# large_movie_review_dataset\test\pos/10824_7.txt
# large_movie_review_dataset\test\pos/10832_9.txt
# large_movie_review_dataset\test\pos/1083_7.txt
# large_movie_review_dataset\test\pos/10848_9.txt
# large_movie_review_dataset\test\pos/1085_9.txt
# large_movie_review_dataset\test\pos/10868_9.txt
# large_movie_review_dataset\test\pos/10869_7.txt
# large_movie_review_dataset\test\pos/10874_7.txt
# large_movie_review_dataset\test\pos/10876_7.txt
# large_movie_review_dataset\test\pos/10877_10.txt
# large_movie_review_dataset\test\pos/10886_7.txt
# large_movie_review_dataset\test\pos/10913_7.txt
# large_movie_review_dataset\test\pos/10918_8.txt
# large_movie_review_dataset\test\pos/10923_7.txt
# large_movie_review_dataset\test\pos/10929_7.txt
# large_movie_review_dataset\test\pos/10938_7.txt
# large_movie_review_dataset\test\pos/10939_8.txt
# large_movie_review_dataset\test\pos/10942_7.txt
# large_movie_review_dataset\test\pos/10943_9.txt
# large_movie_review_dataset\test\pos/10944_7.txt
# large_movie_review_dataset\test\pos/10948_8.txt
# large_movie_review_dataset\test\pos/1094_7.txt
# large_movie_review_dataset\test\pos/10950_8.txt
# large_movie_review_dataset\test\pos/10954_7.txt
# large_movie_review_dataset\test\pos/10955_10.txt
# large_movie_review_dataset\test\pos/10974_8.txt
# large_movie_review_dataset\test\pos/10975_10.txt
# large_movie_review_dataset\test\pos/10979_8.txt
# large_movie_review_dataset\test\pos/1099_7.txt
# large_movie_review_dataset\test\pos/109_8.txt
# large_movie_review_dataset\test\pos/10_7.txt
# large_movie_review_dataset\test\pos/11017_8.txt
# large_movie_review_dataset\test\pos/11018_9.txt
# large_movie_review_dataset\test\pos/11019_10.txt
# large_movie_review_dataset\test\pos/1101_8.txt
# large_movie_review_dataset\test\pos/11020_10.txt
# large_movie_review_dataset\test\pos/11027_10.txt
# large_movie_review_dataset\test\pos/1102_9.txt
# large_movie_review_dataset\test\pos/11032_7.txt
# large_movie_review_dataset\test\pos/11058_8.txt
# large_movie_review_dataset\test\pos/11071_10.txt
# large_movie_review_dataset\test\pos/11080_10.txt
# large_movie_review_dataset\test\pos/11081_10.txt
# large_movie_review_dataset\test\pos/11085_7.txt
# large_movie_review_dataset\test\pos/1108_8.txt
# large_movie_review_dataset\test\pos/11106_7.txt
# large_movie_review_dataset\test\pos/11109_7.txt
# large_movie_review_dataset\test\pos/11112_9.txt
# large_movie_review_dataset\test\pos/11114_8.txt
# large_movie_review_dataset\test\pos/11120_7.txt
# large_movie_review_dataset\test\pos/11125_7.txt
# large_movie_review_dataset\test\pos/11141_10.txt
# large_movie_review_dataset\test\pos/11157_9.txt
# large_movie_review_dataset\test\pos/1115_9.txt
# large_movie_review_dataset\test\pos/11160_7.txt
# large_movie_review_dataset\test\pos/11161_9.txt
# large_movie_review_dataset\test\pos/11164_10.txt
# large_movie_review_dataset\test\pos/11165_10.txt
# large_movie_review_dataset\test\pos/11166_10.txt
# large_movie_review_dataset\test\pos/11168_9.txt
# large_movie_review_dataset\test\pos/11173_10.txt
# large_movie_review_dataset\test\pos/11174_8.txt
# large_movie_review_dataset\test\pos/11180_10.txt
# large_movie_review_dataset\test\pos/11185_10.txt
# large_movie_review_dataset\test\pos/11187_10.txt
# large_movie_review_dataset\test\pos/11188_8.txt
# large_movie_review_dataset\test\pos/11189_10.txt
# large_movie_review_dataset\test\pos/11191_10.txt
# large_movie_review_dataset\test\pos/11193_7.txt
# large_movie_review_dataset\test\pos/11202_10.txt
# large_movie_review_dataset\test\pos/11206_9.txt
# large_movie_review_dataset\test\pos/11207_10.txt
# large_movie_review_dataset\test\pos/11208_10.txt
# large_movie_review_dataset\test\pos/1121_7.txt
# large_movie_review_dataset\test\pos/11232_8.txt
# large_movie_review_dataset\test\pos/11234_10.txt
# large_movie_review_dataset\test\pos/11235_10.txt
# large_movie_review_dataset\test\pos/11237_10.txt
# large_movie_review_dataset\test\pos/11238_10.txt
# large_movie_review_dataset\test\pos/11241_10.txt
# large_movie_review_dataset\test\pos/11242_8.txt
# large_movie_review_dataset\test\pos/11243_8.txt
# large_movie_review_dataset\test\pos/11244_8.txt
# large_movie_review_dataset\test\pos/11246_10.txt
# large_movie_review_dataset\test\pos/11247_10.txt
# large_movie_review_dataset\test\pos/11249_10.txt
# large_movie_review_dataset\test\pos/11250_10.txt
# large_movie_review_dataset\test\pos/11252_7.txt
# large_movie_review_dataset\test\pos/11253_10.txt
# large_movie_review_dataset\test\pos/11254_10.txt
# large_movie_review_dataset\test\pos/11255_9.txt
# large_movie_review_dataset\test\pos/11258_8.txt
# large_movie_review_dataset\test\pos/1125_10.txt
# large_movie_review_dataset\test\pos/11260_10.txt
# large_movie_review_dataset\test\pos/11261_10.txt
# large_movie_review_dataset\test\pos/11269_7.txt
# large_movie_review_dataset\test\pos/11270_10.txt
# large_movie_review_dataset\test\pos/11273_10.txt
# large_movie_review_dataset\test\pos/11274_8.txt
# large_movie_review_dataset\test\pos/11275_8.txt
# large_movie_review_dataset\test\pos/11276_7.txt
# large_movie_review_dataset\test\pos/11277_9.txt
# large_movie_review_dataset\test\pos/11278_10.txt
# large_movie_review_dataset\test\pos/11279_10.txt
# large_movie_review_dataset\test\pos/1127_10.txt
# large_movie_review_dataset\test\pos/11280_10.txt
# large_movie_review_dataset\test\pos/11281_9.txt
# large_movie_review_dataset\test\pos/11283_8.txt
# large_movie_review_dataset\test\pos/11285_8.txt
# large_movie_review_dataset\test\pos/11286_8.txt
# large_movie_review_dataset\test\pos/11288_10.txt
# large_movie_review_dataset\test\pos/11289_10.txt
# large_movie_review_dataset\test\pos/11290_7.txt
# large_movie_review_dataset\test\pos/11291_10.txt
# large_movie_review_dataset\test\pos/11292_10.txt
# large_movie_review_dataset\test\pos/11293_8.txt
# large_movie_review_dataset\test\pos/11294_8.txt
# large_movie_review_dataset\test\pos/11296_7.txt
# large_movie_review_dataset\test\pos/1129_9.txt
# large_movie_review_dataset\test\pos/11300_8.txt
# large_movie_review_dataset\test\pos/11305_7.txt
# large_movie_review_dataset\test\pos/11307_8.txt
# large_movie_review_dataset\test\pos/11309_10.txt
# large_movie_review_dataset\test\pos/1130_8.txt
# large_movie_review_dataset\test\pos/11312_9.txt
# large_movie_review_dataset\test\pos/11313_10.txt
# large_movie_review_dataset\test\pos/11315_7.txt
# large_movie_review_dataset\test\pos/1131_10.txt
# large_movie_review_dataset\test\pos/11320_8.txt
# large_movie_review_dataset\test\pos/11323_7.txt
# large_movie_review_dataset\test\pos/1132_8.txt
# large_movie_review_dataset\test\pos/11338_9.txt
# large_movie_review_dataset\test\pos/1133_8.txt
# large_movie_review_dataset\test\pos/1134_8.txt
# large_movie_review_dataset\test\pos/11353_10.txt
# large_movie_review_dataset\test\pos/11357_7.txt
# large_movie_review_dataset\test\pos/11361_10.txt
# large_movie_review_dataset\test\pos/11365_10.txt
# large_movie_review_dataset\test\pos/1136_8.txt
# large_movie_review_dataset\test\pos/11376_10.txt
# large_movie_review_dataset\test\pos/11386_10.txt
# large_movie_review_dataset\test\pos/11394_10.txt
# large_movie_review_dataset\test\pos/11395_10.txt
# large_movie_review_dataset\test\pos/11399_10.txt
# large_movie_review_dataset\test\pos/1139_10.txt
# large_movie_review_dataset\test\pos/113_8.txt
# large_movie_review_dataset\test\pos/11403_9.txt
# large_movie_review_dataset\test\pos/11404_8.txt
# large_movie_review_dataset\test\pos/11406_8.txt
# large_movie_review_dataset\test\pos/11407_7.txt
# large_movie_review_dataset\test\pos/11408_7.txt
# large_movie_review_dataset\test\pos/11409_9.txt
# large_movie_review_dataset\test\pos/11410_7.txt
# large_movie_review_dataset\test\pos/11411_8.txt
# large_movie_review_dataset\test\pos/11412_7.txt
# large_movie_review_dataset\test\pos/11413_10.txt
# large_movie_review_dataset\test\pos/11414_7.txt
# large_movie_review_dataset\test\pos/11415_7.txt
# large_movie_review_dataset\test\pos/11416_7.txt
# large_movie_review_dataset\test\pos/11417_7.txt
# large_movie_review_dataset\test\pos/11418_7.txt
# large_movie_review_dataset\test\pos/11420_7.txt
# large_movie_review_dataset\test\pos/11422_7.txt
# large_movie_review_dataset\test\pos/11424_8.txt
# large_movie_review_dataset\test\pos/11440_8.txt
# large_movie_review_dataset\test\pos/11443_8.txt
# large_movie_review_dataset\test\pos/11444_8.txt
# large_movie_review_dataset\test\pos/11445_8.txt
# large_movie_review_dataset\test\pos/11447_8.txt
# large_movie_review_dataset\test\pos/11448_8.txt
# large_movie_review_dataset\test\pos/11449_8.txt
# large_movie_review_dataset\test\pos/11450_10.txt
# large_movie_review_dataset\test\pos/11452_7.txt
# large_movie_review_dataset\test\pos/11453_7.txt
# large_movie_review_dataset\test\pos/11454_7.txt
# large_movie_review_dataset\test\pos/11456_10.txt
# large_movie_review_dataset\test\pos/11457_10.txt
# large_movie_review_dataset\test\pos/11458_10.txt
# large_movie_review_dataset\test\pos/11459_10.txt
# large_movie_review_dataset\test\pos/11460_10.txt
# large_movie_review_dataset\test\pos/11461_9.txt
# large_movie_review_dataset\test\pos/11462_10.txt
# large_movie_review_dataset\test\pos/11463_9.txt
# large_movie_review_dataset\test\pos/11464_8.txt
# large_movie_review_dataset\test\pos/11465_10.txt
# large_movie_review_dataset\test\pos/11466_8.txt
# large_movie_review_dataset\test\pos/11468_8.txt
# large_movie_review_dataset\test\pos/11470_10.txt
# large_movie_review_dataset\test\pos/11471_7.txt
# large_movie_review_dataset\test\pos/11472_7.txt
# large_movie_review_dataset\test\pos/11473_10.txt
# large_movie_review_dataset\test\pos/11475_7.txt
# large_movie_review_dataset\test\pos/11481_10.txt
# large_movie_review_dataset\test\pos/11482_7.txt
# large_movie_review_dataset\test\pos/114_10.txt
# large_movie_review_dataset\test\pos/11503_8.txt
# large_movie_review_dataset\test\pos/11519_7.txt
# large_movie_review_dataset\test\pos/11526_8.txt
# large_movie_review_dataset\test\pos/11534_7.txt
# large_movie_review_dataset\test\pos/11537_7.txt
# large_movie_review_dataset\test\pos/11538_8.txt
# large_movie_review_dataset\test\pos/11540_10.txt
# large_movie_review_dataset\test\pos/11543_10.txt
# large_movie_review_dataset\test\pos/11550_10.txt
# large_movie_review_dataset\test\pos/11557_7.txt
# large_movie_review_dataset\test\pos/11565_7.txt
# large_movie_review_dataset\test\pos/11569_7.txt
# large_movie_review_dataset\test\pos/11577_10.txt
# large_movie_review_dataset\test\pos/1157_9.txt
# large_movie_review_dataset\test\pos/11580_7.txt
# large_movie_review_dataset\test\pos/11598_10.txt
# large_movie_review_dataset\test\pos/11605_7.txt
# large_movie_review_dataset\test\pos/11608_9.txt
# large_movie_review_dataset\test\pos/11614_9.txt
# large_movie_review_dataset\test\pos/11615_8.txt
# large_movie_review_dataset\test\pos/11617_8.txt
# large_movie_review_dataset\test\pos/11618_10.txt
# large_movie_review_dataset\test\pos/11619_9.txt
# large_movie_review_dataset\test\pos/1161_10.txt
# large_movie_review_dataset\test\pos/11627_8.txt
# large_movie_review_dataset\test\pos/11630_7.txt
# large_movie_review_dataset\test\pos/11631_7.txt
# large_movie_review_dataset\test\pos/11632_10.txt
# large_movie_review_dataset\test\pos/11633_8.txt
# large_movie_review_dataset\test\pos/11634_10.txt
# large_movie_review_dataset\test\pos/11635_7.txt
# large_movie_review_dataset\test\pos/11636_9.txt
# large_movie_review_dataset\test\pos/11637_8.txt
# large_movie_review_dataset\test\pos/11642_8.txt
# large_movie_review_dataset\test\pos/11646_8.txt
# large_movie_review_dataset\test\pos/11647_10.txt
# large_movie_review_dataset\test\pos/11656_8.txt
# large_movie_review_dataset\test\pos/11659_10.txt
# large_movie_review_dataset\test\pos/11660_10.txt
# large_movie_review_dataset\test\pos/11661_10.txt
# large_movie_review_dataset\test\pos/11669_10.txt
# large_movie_review_dataset\test\pos/1166_10.txt
# large_movie_review_dataset\test\pos/11670_7.txt
# large_movie_review_dataset\test\pos/11675_10.txt
# large_movie_review_dataset\test\pos/11676_10.txt
# large_movie_review_dataset\test\pos/11677_10.txt
# large_movie_review_dataset\test\pos/11698_10.txt
# large_movie_review_dataset\test\pos/11699_8.txt
# large_movie_review_dataset\test\pos/11701_8.txt
# large_movie_review_dataset\test\pos/11702_8.txt
# large_movie_review_dataset\test\pos/11707_10.txt
# large_movie_review_dataset\test\pos/11712_7.txt
# large_movie_review_dataset\test\pos/11716_10.txt
# large_movie_review_dataset\test\pos/11750_10.txt
# large_movie_review_dataset\test\pos/11761_7.txt
# large_movie_review_dataset\test\pos/11764_7.txt
# large_movie_review_dataset\test\pos/11766_7.txt
# large_movie_review_dataset\test\pos/11772_7.txt
# large_movie_review_dataset\test\pos/11773_10.txt
# large_movie_review_dataset\test\pos/11775_10.txt
# large_movie_review_dataset\test\pos/11776_10.txt
# large_movie_review_dataset\test\pos/11777_9.txt
# large_movie_review_dataset\test\pos/11778_10.txt
# large_movie_review_dataset\test\pos/11779_10.txt
# large_movie_review_dataset\test\pos/11780_8.txt
# large_movie_review_dataset\test\pos/11782_8.txt
# large_movie_review_dataset\test\pos/11784_10.txt
# large_movie_review_dataset\test\pos/11785_10.txt
# large_movie_review_dataset\test\pos/11787_10.txt
# large_movie_review_dataset\test\pos/11792_10.txt
# large_movie_review_dataset\test\pos/11796_10.txt
# large_movie_review_dataset\test\pos/11801_10.txt
# large_movie_review_dataset\test\pos/11807_8.txt
# large_movie_review_dataset\test\pos/11827_10.txt
# large_movie_review_dataset\test\pos/11828_7.txt
# large_movie_review_dataset\test\pos/11840_10.txt
# large_movie_review_dataset\test\pos/11844_9.txt
# large_movie_review_dataset\test\pos/11846_9.txt
# large_movie_review_dataset\test\pos/11850_7.txt
# large_movie_review_dataset\test\pos/11851_8.txt
# large_movie_review_dataset\test\pos/11858_7.txt
# large_movie_review_dataset\test\pos/11859_8.txt
# large_movie_review_dataset\test\pos/11862_7.txt
# large_movie_review_dataset\test\pos/11865_7.txt
# large_movie_review_dataset\test\pos/11866_10.txt
# large_movie_review_dataset\test\pos/11879_10.txt
# large_movie_review_dataset\test\pos/11880_10.txt
# large_movie_review_dataset\test\pos/11881_10.txt
# large_movie_review_dataset\test\pos/11882_10.txt
# large_movie_review_dataset\test\pos/11905_10.txt
# large_movie_review_dataset\test\pos/11906_8.txt
# large_movie_review_dataset\test\pos/11908_9.txt
# large_movie_review_dataset\test\pos/11909_10.txt
# large_movie_review_dataset\test\pos/11910_10.txt
# large_movie_review_dataset\test\pos/11911_8.txt
# large_movie_review_dataset\test\pos/11913_7.txt
# large_movie_review_dataset\test\pos/11914_7.txt
# large_movie_review_dataset\test\pos/11918_10.txt
# large_movie_review_dataset\test\pos/11925_10.txt
# large_movie_review_dataset\test\pos/11928_8.txt
# large_movie_review_dataset\test\pos/11929_10.txt
# large_movie_review_dataset\test\pos/11930_8.txt
# large_movie_review_dataset\test\pos/11931_8.txt
# large_movie_review_dataset\test\pos/11936_8.txt
# large_movie_review_dataset\test\pos/11939_7.txt
# large_movie_review_dataset\test\pos/11941_7.txt
# large_movie_review_dataset\test\pos/11944_8.txt
# large_movie_review_dataset\test\pos/11945_7.txt
# large_movie_review_dataset\test\pos/11946_7.txt
# large_movie_review_dataset\test\pos/11948_10.txt
# large_movie_review_dataset\test\pos/11950_7.txt
# large_movie_review_dataset\test\pos/11951_10.txt
# large_movie_review_dataset\test\pos/11953_10.txt
# large_movie_review_dataset\test\pos/11954_9.txt
# large_movie_review_dataset\test\pos/11956_8.txt
# large_movie_review_dataset\test\pos/11957_10.txt
# large_movie_review_dataset\test\pos/11958_8.txt
# large_movie_review_dataset\test\pos/11969_10.txt
# large_movie_review_dataset\test\pos/1196_9.txt
# large_movie_review_dataset\test\pos/11970_10.txt
# large_movie_review_dataset\test\pos/11971_8.txt
# large_movie_review_dataset\test\pos/11972_7.txt
# large_movie_review_dataset\test\pos/11973_10.txt
# large_movie_review_dataset\test\pos/11974_7.txt
# large_movie_review_dataset\test\pos/11976_10.txt
# large_movie_review_dataset\test\pos/11979_10.txt
# large_movie_review_dataset\test\pos/11981_10.txt
# large_movie_review_dataset\test\pos/11986_7.txt
# large_movie_review_dataset\test\pos/11987_10.txt
# large_movie_review_dataset\test\pos/11988_10.txt
# large_movie_review_dataset\test\pos/11990_10.txt
# large_movie_review_dataset\test\pos/11991_10.txt
# large_movie_review_dataset\test\pos/11992_10.txt
# large_movie_review_dataset\test\pos/11993_10.txt
# large_movie_review_dataset\test\pos/11994_9.txt
# large_movie_review_dataset\test\pos/11995_7.txt
# large_movie_review_dataset\test\pos/11996_7.txt
# large_movie_review_dataset\test\pos/11999_8.txt
# large_movie_review_dataset\test\pos/11_8.txt
# large_movie_review_dataset\test\pos/12002_8.txt
# large_movie_review_dataset\test\pos/12003_9.txt
# large_movie_review_dataset\test\pos/12010_8.txt
# large_movie_review_dataset\test\pos/12020_10.txt
# large_movie_review_dataset\test\pos/12027_10.txt
# large_movie_review_dataset\test\pos/12032_7.txt
# large_movie_review_dataset\test\pos/12033_7.txt
# large_movie_review_dataset\test\pos/12034_10.txt
# large_movie_review_dataset\test\pos/12051_10.txt
# large_movie_review_dataset\test\pos/12052_8.txt
# large_movie_review_dataset\test\pos/12054_9.txt
# large_movie_review_dataset\test\pos/12056_9.txt
# large_movie_review_dataset\test\pos/12058_9.txt
# large_movie_review_dataset\test\pos/12062_10.txt
# large_movie_review_dataset\test\pos/12064_10.txt
# large_movie_review_dataset\test\pos/12067_7.txt
# large_movie_review_dataset\test\pos/12070_8.txt
# large_movie_review_dataset\test\pos/12078_8.txt
# large_movie_review_dataset\test\pos/12088_7.txt
# large_movie_review_dataset\test\pos/12092_8.txt
# large_movie_review_dataset\test\pos/12105_10.txt
# large_movie_review_dataset\test\pos/12122_10.txt
# large_movie_review_dataset\test\pos/12123_7.txt
# large_movie_review_dataset\test\pos/12132_8.txt
# large_movie_review_dataset\test\pos/12136_8.txt
# large_movie_review_dataset\test\pos/12137_8.txt
# large_movie_review_dataset\test\pos/12138_7.txt
# large_movie_review_dataset\test\pos/12139_7.txt
# large_movie_review_dataset\test\pos/1213_7.txt
# large_movie_review_dataset\test\pos/12140_8.txt
# large_movie_review_dataset\test\pos/12152_10.txt
# large_movie_review_dataset\test\pos/12154_7.txt
# large_movie_review_dataset\test\pos/12171_9.txt
# large_movie_review_dataset\test\pos/12172_8.txt
# large_movie_review_dataset\test\pos/12173_9.txt
# large_movie_review_dataset\test\pos/12174_10.txt
# large_movie_review_dataset\test\pos/12175_9.txt
# large_movie_review_dataset\test\pos/12176_10.txt
# large_movie_review_dataset\test\pos/12178_7.txt
# large_movie_review_dataset\test\pos/12179_7.txt
# large_movie_review_dataset\test\pos/12180_7.txt
# large_movie_review_dataset\test\pos/12182_10.txt
# large_movie_review_dataset\test\pos/12183_9.txt
# large_movie_review_dataset\test\pos/12185_10.txt
# large_movie_review_dataset\test\pos/12186_10.txt
# large_movie_review_dataset\test\pos/12190_9.txt
# large_movie_review_dataset\test\pos/12191_9.txt
# large_movie_review_dataset\test\pos/12193_8.txt
# large_movie_review_dataset\test\pos/12195_10.txt
# large_movie_review_dataset\test\pos/12196_7.txt
# large_movie_review_dataset\test\pos/12199_7.txt
# large_movie_review_dataset\test\pos/12200_10.txt
# large_movie_review_dataset\test\pos/12206_10.txt
# large_movie_review_dataset\test\pos/12208_9.txt
# large_movie_review_dataset\test\pos/12209_9.txt
# large_movie_review_dataset\test\pos/12210_10.txt
# large_movie_review_dataset\test\pos/12211_10.txt
# large_movie_review_dataset\test\pos/12212_10.txt
# large_movie_review_dataset\test\pos/12214_10.txt
# large_movie_review_dataset\test\pos/12215_10.txt
# large_movie_review_dataset\test\pos/12216_10.txt
# large_movie_review_dataset\test\pos/12218_8.txt
# large_movie_review_dataset\test\pos/12219_7.txt
# large_movie_review_dataset\test\pos/12220_8.txt
# large_movie_review_dataset\test\pos/12222_7.txt
# large_movie_review_dataset\test\pos/12223_7.txt
# large_movie_review_dataset\test\pos/12224_9.txt
# large_movie_review_dataset\test\pos/12226_7.txt
# large_movie_review_dataset\test\pos/1222_8.txt
# large_movie_review_dataset\test\pos/12232_8.txt
# large_movie_review_dataset\test\pos/12237_10.txt
# large_movie_review_dataset\test\pos/12238_10.txt
# large_movie_review_dataset\test\pos/1223_8.txt
# large_movie_review_dataset\test\pos/12241_8.txt
# large_movie_review_dataset\test\pos/12250_10.txt
# large_movie_review_dataset\test\pos/12277_7.txt
# large_movie_review_dataset\test\pos/1227_7.txt
# large_movie_review_dataset\test\pos/12282_10.txt
# large_movie_review_dataset\test\pos/1228_7.txt
# large_movie_review_dataset\test\pos/12290_10.txt
# large_movie_review_dataset\test\pos/12297_7.txt
# large_movie_review_dataset\test\pos/1229_7.txt
# large_movie_review_dataset\test\pos/122_8.txt
# large_movie_review_dataset\test\pos/12301_10.txt
# large_movie_review_dataset\test\pos/1231_7.txt
# large_movie_review_dataset\test\pos/12329_8.txt
# large_movie_review_dataset\test\pos/12330_8.txt
# large_movie_review_dataset\test\pos/12331_9.txt
# large_movie_review_dataset\test\pos/12332_7.txt
# large_movie_review_dataset\test\pos/12333_7.txt
# large_movie_review_dataset\test\pos/12335_7.txt
# large_movie_review_dataset\test\pos/12336_7.txt
# large_movie_review_dataset\test\pos/12338_8.txt
# large_movie_review_dataset\test\pos/12339_7.txt
# large_movie_review_dataset\test\pos/12340_8.txt
# large_movie_review_dataset\test\pos/12342_7.txt
# large_movie_review_dataset\test\pos/12345_10.txt
# large_movie_review_dataset\test\pos/12347_10.txt
# large_movie_review_dataset\test\pos/12348_10.txt
# large_movie_review_dataset\test\pos/12354_8.txt
# large_movie_review_dataset\test\pos/12356_10.txt
# large_movie_review_dataset\test\pos/12364_7.txt
# large_movie_review_dataset\test\pos/12376_10.txt
# large_movie_review_dataset\test\pos/12377_10.txt
# large_movie_review_dataset\test\pos/12378_7.txt
# large_movie_review_dataset\test\pos/12379_7.txt
# large_movie_review_dataset\test\pos/12380_7.txt
# large_movie_review_dataset\test\pos/12382_9.txt
# large_movie_review_dataset\test\pos/12383_10.txt
# large_movie_review_dataset\test\pos/12384_10.txt
# large_movie_review_dataset\test\pos/12385_10.txt
# large_movie_review_dataset\test\pos/12386_10.txt
# large_movie_review_dataset\test\pos/12387_8.txt
# large_movie_review_dataset\test\pos/12388_7.txt
# large_movie_review_dataset\test\pos/12398_10.txt
# large_movie_review_dataset\test\pos/1239_10.txt
# large_movie_review_dataset\test\pos/12401_10.txt
# large_movie_review_dataset\test\pos/12413_9.txt
# large_movie_review_dataset\test\pos/12414_8.txt
# large_movie_review_dataset\test\pos/12416_7.txt
# large_movie_review_dataset\test\pos/12417_9.txt
# large_movie_review_dataset\test\pos/12419_8.txt
# large_movie_review_dataset\test\pos/1241_7.txt
# large_movie_review_dataset\test\pos/12420_10.txt
# large_movie_review_dataset\test\pos/12422_7.txt
# large_movie_review_dataset\test\pos/12423_9.txt
# large_movie_review_dataset\test\pos/12424_7.txt
# large_movie_review_dataset\test\pos/12426_7.txt
# large_movie_review_dataset\test\pos/12427_8.txt
# large_movie_review_dataset\test\pos/12428_7.txt
# large_movie_review_dataset\test\pos/12429_10.txt
# large_movie_review_dataset\test\pos/1242_7.txt
# large_movie_review_dataset\test\pos/12430_8.txt
# large_movie_review_dataset\test\pos/12432_7.txt
# large_movie_review_dataset\test\pos/12433_8.txt
# large_movie_review_dataset\test\pos/1243_7.txt
# large_movie_review_dataset\test\pos/12447_7.txt
# large_movie_review_dataset\test\pos/12448_10.txt
# large_movie_review_dataset\test\pos/12456_8.txt
# large_movie_review_dataset\test\pos/12459_10.txt
# large_movie_review_dataset\test\pos/12477_7.txt
# large_movie_review_dataset\test\pos/12494_8.txt
# large_movie_review_dataset\test\pos/12495_10.txt
# large_movie_review_dataset\test\pos/12496_10.txt
# large_movie_review_dataset\test\pos/12498_7.txt
# large_movie_review_dataset\test\pos/1253_9.txt
# large_movie_review_dataset\test\pos/1257_10.txt
# large_movie_review_dataset\test\pos/1259_10.txt
# large_movie_review_dataset\test\pos/1261_7.txt
# large_movie_review_dataset\test\pos/1263_9.txt
# large_movie_review_dataset\test\pos/1265_10.txt
# large_movie_review_dataset\test\pos/1268_8.txt
# large_movie_review_dataset\test\pos/1273_7.txt
# large_movie_review_dataset\test\pos/1275_7.txt
# large_movie_review_dataset\test\pos/1296_8.txt
# large_movie_review_dataset\test\pos/1298_8.txt
# large_movie_review_dataset\test\pos/1299_9.txt
# large_movie_review_dataset\test\pos/1306_8.txt
# large_movie_review_dataset\test\pos/1311_9.txt
# large_movie_review_dataset\test\pos/1327_9.txt
# large_movie_review_dataset\test\pos/1329_7.txt
# large_movie_review_dataset\test\pos/1330_10.txt
# large_movie_review_dataset\test\pos/1331_9.txt
# large_movie_review_dataset\test\pos/1335_7.txt
# large_movie_review_dataset\test\pos/1337_10.txt
# large_movie_review_dataset\test\pos/1338_7.txt
# large_movie_review_dataset\test\pos/1339_8.txt
# large_movie_review_dataset\test\pos/1340_10.txt
# large_movie_review_dataset\test\pos/1342_10.txt
# large_movie_review_dataset\test\pos/1343_10.txt
# large_movie_review_dataset\test\pos/1345_9.txt
# large_movie_review_dataset\test\pos/1346_7.txt
# large_movie_review_dataset\test\pos/1358_10.txt
# large_movie_review_dataset\test\pos/1359_10.txt
# large_movie_review_dataset\test\pos/1363_10.txt
# large_movie_review_dataset\test\pos/1364_10.txt
# large_movie_review_dataset\test\pos/1367_10.txt
# large_movie_review_dataset\test\pos/1368_8.txt
# large_movie_review_dataset\test\pos/1369_7.txt
# large_movie_review_dataset\test\pos/1370_10.txt
# large_movie_review_dataset\test\pos/1371_8.txt
# large_movie_review_dataset\test\pos/1372_10.txt
# large_movie_review_dataset\test\pos/1373_10.txt
# large_movie_review_dataset\test\pos/1376_8.txt
# large_movie_review_dataset\test\pos/1377_10.txt
# large_movie_review_dataset\test\pos/1378_10.txt
# large_movie_review_dataset\test\pos/1379_10.txt
# large_movie_review_dataset\test\pos/1380_9.txt
# large_movie_review_dataset\test\pos/1381_7.txt
# large_movie_review_dataset\test\pos/1382_10.txt
# large_movie_review_dataset\test\pos/1383_10.txt
# large_movie_review_dataset\test\pos/1388_8.txt
# large_movie_review_dataset\test\pos/1392_7.txt
# large_movie_review_dataset\test\pos/1393_8.txt
# large_movie_review_dataset\test\pos/1394_9.txt
# large_movie_review_dataset\test\pos/1395_7.txt
# large_movie_review_dataset\test\pos/1396_8.txt
# large_movie_review_dataset\test\pos/1397_10.txt
# large_movie_review_dataset\test\pos/1398_8.txt
# large_movie_review_dataset\test\pos/139_9.txt
# large_movie_review_dataset\test\pos/140_9.txt
# large_movie_review_dataset\test\pos/1413_9.txt
# large_movie_review_dataset\test\pos/1425_8.txt
# large_movie_review_dataset\test\pos/143_8.txt
# large_movie_review_dataset\test\pos/1448_8.txt
# large_movie_review_dataset\test\pos/1459_7.txt
# large_movie_review_dataset\test\pos/145_9.txt
# large_movie_review_dataset\test\pos/1461_7.txt
# large_movie_review_dataset\test\pos/1470_8.txt
# large_movie_review_dataset\test\pos/1472_10.txt
# large_movie_review_dataset\test\pos/1473_7.txt
# large_movie_review_dataset\test\pos/1478_8.txt
# large_movie_review_dataset\test\pos/1480_7.txt
# large_movie_review_dataset\test\pos/1481_10.txt
# large_movie_review_dataset\test\pos/148_9.txt
# large_movie_review_dataset\test\pos/1502_10.txt
# large_movie_review_dataset\test\pos/1503_8.txt
# large_movie_review_dataset\test\pos/1504_9.txt
# large_movie_review_dataset\test\pos/1506_7.txt
# large_movie_review_dataset\test\pos/1508_7.txt
# large_movie_review_dataset\test\pos/1509_8.txt
# large_movie_review_dataset\test\pos/1510_8.txt
# large_movie_review_dataset\test\pos/1511_9.txt
# large_movie_review_dataset\test\pos/1513_8.txt
# large_movie_review_dataset\test\pos/1514_7.txt
# large_movie_review_dataset\test\pos/1515_7.txt
# large_movie_review_dataset\test\pos/1516_7.txt
# large_movie_review_dataset\test\pos/1519_9.txt
# large_movie_review_dataset\test\pos/1525_10.txt
# large_movie_review_dataset\test\pos/152_10.txt
# large_movie_review_dataset\test\pos/1531_9.txt
# large_movie_review_dataset\test\pos/1534_10.txt
# large_movie_review_dataset\test\pos/1536_10.txt
# large_movie_review_dataset\test\pos/1538_7.txt
# large_movie_review_dataset\test\pos/1542_7.txt
# large_movie_review_dataset\test\pos/1543_7.txt
# large_movie_review_dataset\test\pos/1551_7.txt
# large_movie_review_dataset\test\pos/1554_8.txt
# large_movie_review_dataset\test\pos/1557_10.txt
# large_movie_review_dataset\test\pos/1567_7.txt
# large_movie_review_dataset\test\pos/1570_8.txt
# large_movie_review_dataset\test\pos/1576_7.txt
# large_movie_review_dataset\test\pos/1577_8.txt
# large_movie_review_dataset\test\pos/1578_7.txt
# large_movie_review_dataset\test\pos/1579_7.txt
# large_movie_review_dataset\test\pos/1580_8.txt
# large_movie_review_dataset\test\pos/1581_8.txt
# large_movie_review_dataset\test\pos/1582_8.txt
# large_movie_review_dataset\test\pos/1586_7.txt
# large_movie_review_dataset\test\pos/1593_10.txt
# large_movie_review_dataset\test\pos/1599_7.txt
# large_movie_review_dataset\test\pos/15_10.txt
# large_movie_review_dataset\test\pos/1601_10.txt
# large_movie_review_dataset\test\pos/1603_10.txt
# large_movie_review_dataset\test\pos/1616_8.txt
# large_movie_review_dataset\test\pos/1617_7.txt
# large_movie_review_dataset\test\pos/1618_10.txt
# large_movie_review_dataset\test\pos/1619_10.txt
# large_movie_review_dataset\test\pos/161_7.txt
# large_movie_review_dataset\test\pos/1620_7.txt
# large_movie_review_dataset\test\pos/1621_9.txt
# large_movie_review_dataset\test\pos/1622_9.txt
# large_movie_review_dataset\test\pos/1628_8.txt
# large_movie_review_dataset\test\pos/162_8.txt
# large_movie_review_dataset\test\pos/1631_7.txt
# large_movie_review_dataset\test\pos/1632_7.txt
# large_movie_review_dataset\test\pos/1634_7.txt
# large_movie_review_dataset\test\pos/1636_8.txt
# large_movie_review_dataset\test\pos/1639_10.txt
# large_movie_review_dataset\test\pos/163_7.txt
# large_movie_review_dataset\test\pos/1642_10.txt
# large_movie_review_dataset\test\pos/1646_7.txt
# large_movie_review_dataset\test\pos/164_7.txt
# large_movie_review_dataset\test\pos/1667_10.txt
# large_movie_review_dataset\test\pos/1668_7.txt
# large_movie_review_dataset\test\pos/166_7.txt
# large_movie_review_dataset\test\pos/1677_10.txt
# large_movie_review_dataset\test\pos/1696_10.txt
# large_movie_review_dataset\test\pos/1698_10.txt
# large_movie_review_dataset\test\pos/1699_8.txt
# large_movie_review_dataset\test\pos/169_7.txt
# large_movie_review_dataset\test\pos/1700_8.txt
# large_movie_review_dataset\test\pos/1701_7.txt
# large_movie_review_dataset\test\pos/1703_7.txt
# large_movie_review_dataset\test\pos/1705_7.txt
# large_movie_review_dataset\test\pos/1707_8.txt
# large_movie_review_dataset\test\pos/1708_7.txt
# large_movie_review_dataset\test\pos/1709_7.txt
# large_movie_review_dataset\test\pos/170_7.txt
# large_movie_review_dataset\test\pos/1714_10.txt
# large_movie_review_dataset\test\pos/1717_10.txt
# large_movie_review_dataset\test\pos/1729_10.txt
# large_movie_review_dataset\test\pos/1734_10.txt
# large_movie_review_dataset\test\pos/1737_8.txt
# large_movie_review_dataset\test\pos/1739_10.txt
# large_movie_review_dataset\test\pos/1741_10.txt
# large_movie_review_dataset\test\pos/1743_8.txt
# large_movie_review_dataset\test\pos/1749_10.txt
# large_movie_review_dataset\test\pos/175_8.txt
# large_movie_review_dataset\test\pos/1789_7.txt
# large_movie_review_dataset\test\pos/1805_7.txt
# large_movie_review_dataset\test\pos/1807_7.txt
# large_movie_review_dataset\test\pos/1810_10.txt
# large_movie_review_dataset\test\pos/1812_8.txt
# large_movie_review_dataset\test\pos/1817_10.txt
# large_movie_review_dataset\test\pos/1836_7.txt
# large_movie_review_dataset\test\pos/1856_7.txt
# large_movie_review_dataset\test\pos/1862_8.txt
# large_movie_review_dataset\test\pos/1873_7.txt
# large_movie_review_dataset\test\pos/1874_9.txt
# large_movie_review_dataset\test\pos/1875_7.txt
# large_movie_review_dataset\test\pos/1876_10.txt
# large_movie_review_dataset\test\pos/1877_7.txt
# large_movie_review_dataset\test\pos/1878_8.txt
# large_movie_review_dataset\test\pos/1879_7.txt
# large_movie_review_dataset\test\pos/1881_10.txt
# large_movie_review_dataset\test\pos/1883_9.txt
# large_movie_review_dataset\test\pos/1884_7.txt
# large_movie_review_dataset\test\pos/1885_8.txt
# large_movie_review_dataset\test\pos/1887_7.txt
# large_movie_review_dataset\test\pos/1888_9.txt
# large_movie_review_dataset\test\pos/1889_8.txt
# large_movie_review_dataset\test\pos/1892_10.txt
# large_movie_review_dataset\test\pos/1894_10.txt
# large_movie_review_dataset\test\pos/1895_10.txt
# large_movie_review_dataset\test\pos/1896_10.txt
# large_movie_review_dataset\test\pos/1899_10.txt
# large_movie_review_dataset\test\pos/1901_10.txt
# large_movie_review_dataset\test\pos/1904_10.txt
# large_movie_review_dataset\test\pos/1905_8.txt
# large_movie_review_dataset\test\pos/1906_7.txt
# large_movie_review_dataset\test\pos/1908_10.txt
# large_movie_review_dataset\test\pos/1909_9.txt
# large_movie_review_dataset\test\pos/1911_8.txt
# large_movie_review_dataset\test\pos/1912_8.txt
# large_movie_review_dataset\test\pos/1913_10.txt
# large_movie_review_dataset\test\pos/1915_8.txt
# large_movie_review_dataset\test\pos/1916_7.txt
# large_movie_review_dataset\test\pos/1922_10.txt
# large_movie_review_dataset\test\pos/1941_7.txt
# large_movie_review_dataset\test\pos/1943_7.txt
# large_movie_review_dataset\test\pos/1949_10.txt
# large_movie_review_dataset\test\pos/1953_10.txt
# large_movie_review_dataset\test\pos/1954_8.txt
# large_movie_review_dataset\test\pos/1957_10.txt
# large_movie_review_dataset\test\pos/1967_10.txt
# large_movie_review_dataset\test\pos/1971_7.txt
# large_movie_review_dataset\test\pos/1972_7.txt
# large_movie_review_dataset\test\pos/1974_9.txt
# large_movie_review_dataset\test\pos/1975_9.txt
# large_movie_review_dataset\test\pos/1978_7.txt
# large_movie_review_dataset\test\pos/1982_8.txt
# large_movie_review_dataset\test\pos/1983_9.txt
# large_movie_review_dataset\test\pos/1984_8.txt
# large_movie_review_dataset\test\pos/1989_8.txt
# large_movie_review_dataset\test\pos/1993_10.txt
# large_movie_review_dataset\test\pos/1995_10.txt
# large_movie_review_dataset\test\pos/1996_10.txt
# large_movie_review_dataset\test\pos/1997_8.txt
# large_movie_review_dataset\test\pos/1998_8.txt
# large_movie_review_dataset\test\pos/1999_7.txt
# large_movie_review_dataset\test\pos/2000_9.txt
# large_movie_review_dataset\test\pos/2002_9.txt
# large_movie_review_dataset\test\pos/2003_10.txt
# large_movie_review_dataset\test\pos/2004_10.txt
# large_movie_review_dataset\test\pos/2016_10.txt
# large_movie_review_dataset\test\pos/2023_7.txt
# large_movie_review_dataset\test\pos/2025_9.txt
# large_movie_review_dataset\test\pos/2029_8.txt
# large_movie_review_dataset\test\pos/2031_10.txt
# large_movie_review_dataset\test\pos/2032_7.txt
# large_movie_review_dataset\test\pos/2033_8.txt
# large_movie_review_dataset\test\pos/2034_7.txt
# large_movie_review_dataset\test\pos/2041_7.txt
# large_movie_review_dataset\test\pos/2043_7.txt
# large_movie_review_dataset\test\pos/2047_9.txt
# large_movie_review_dataset\test\pos/2051_7.txt
# large_movie_review_dataset\test\pos/2052_10.txt
# large_movie_review_dataset\test\pos/2055_9.txt
# large_movie_review_dataset\test\pos/2060_10.txt
# large_movie_review_dataset\test\pos/2063_10.txt
# large_movie_review_dataset\test\pos/2064_8.txt
# large_movie_review_dataset\test\pos/2066_10.txt
# large_movie_review_dataset\test\pos/2070_10.txt
# large_movie_review_dataset\test\pos/208_10.txt
# large_movie_review_dataset\test\pos/2094_10.txt
# large_movie_review_dataset\test\pos/2097_8.txt
# large_movie_review_dataset\test\pos/2099_7.txt
# large_movie_review_dataset\test\pos/2101_8.txt
# large_movie_review_dataset\test\pos/2107_7.txt
# large_movie_review_dataset\test\pos/2108_8.txt
# large_movie_review_dataset\test\pos/2110_7.txt
# large_movie_review_dataset\test\pos/2118_10.txt
# large_movie_review_dataset\test\pos/212_7.txt
# large_movie_review_dataset\test\pos/2130_7.txt
# large_movie_review_dataset\test\pos/2132_8.txt
# large_movie_review_dataset\test\pos/2134_7.txt
# large_movie_review_dataset\test\pos/2142_9.txt
# large_movie_review_dataset\test\pos/2144_9.txt
# large_movie_review_dataset\test\pos/2156_10.txt
# large_movie_review_dataset\test\pos/2158_10.txt
# large_movie_review_dataset\test\pos/2159_7.txt
# large_movie_review_dataset\test\pos/2160_7.txt
# large_movie_review_dataset\test\pos/2166_8.txt
# large_movie_review_dataset\test\pos/2167_9.txt
# large_movie_review_dataset\test\pos/2169_7.txt
# large_movie_review_dataset\test\pos/2170_8.txt
# large_movie_review_dataset\test\pos/2178_7.txt
# large_movie_review_dataset\test\pos/2179_7.txt
# large_movie_review_dataset\test\pos/2184_7.txt
# large_movie_review_dataset\test\pos/2191_10.txt
# large_movie_review_dataset\test\pos/2221_8.txt
# large_movie_review_dataset\test\pos/2224_10.txt
# large_movie_review_dataset\test\pos/2225_10.txt
# large_movie_review_dataset\test\pos/2226_10.txt
# large_movie_review_dataset\test\pos/2227_10.txt
# large_movie_review_dataset\test\pos/2228_10.txt
# large_movie_review_dataset\test\pos/222_10.txt
# large_movie_review_dataset\test\pos/2230_9.txt
# large_movie_review_dataset\test\pos/2231_7.txt
# large_movie_review_dataset\test\pos/2235_7.txt
# large_movie_review_dataset\test\pos/2237_7.txt
# large_movie_review_dataset\test\pos/2239_8.txt
# large_movie_review_dataset\test\pos/2240_10.txt
# large_movie_review_dataset\test\pos/2248_10.txt
# large_movie_review_dataset\test\pos/224_10.txt
# large_movie_review_dataset\test\pos/2250_8.txt
# large_movie_review_dataset\test\pos/225_10.txt
# large_movie_review_dataset\test\pos/2268_10.txt
# large_movie_review_dataset\test\pos/227_10.txt
# large_movie_review_dataset\test\pos/2285_8.txt
# large_movie_review_dataset\test\pos/228_10.txt
# large_movie_review_dataset\test\pos/2292_10.txt
# large_movie_review_dataset\test\pos/2296_9.txt
# large_movie_review_dataset\test\pos/229_10.txt
# large_movie_review_dataset\test\pos/2300_9.txt
# large_movie_review_dataset\test\pos/2309_10.txt
# large_movie_review_dataset\test\pos/2311_9.txt
# large_movie_review_dataset\test\pos/2313_8.txt
# large_movie_review_dataset\test\pos/2314_10.txt
# large_movie_review_dataset\test\pos/2316_8.txt
# large_movie_review_dataset\test\pos/2317_7.txt
# large_movie_review_dataset\test\pos/2320_10.txt
# large_movie_review_dataset\test\pos/2321_8.txt
# large_movie_review_dataset\test\pos/2322_7.txt
# large_movie_review_dataset\test\pos/2329_10.txt
# large_movie_review_dataset\test\pos/2332_8.txt
# large_movie_review_dataset\test\pos/2333_8.txt
# large_movie_review_dataset\test\pos/2344_10.txt
# large_movie_review_dataset\test\pos/2359_10.txt
# large_movie_review_dataset\test\pos/2363_10.txt
# large_movie_review_dataset\test\pos/2369_8.txt
# large_movie_review_dataset\test\pos/2379_9.txt
# large_movie_review_dataset\test\pos/2383_8.txt
# large_movie_review_dataset\test\pos/2395_9.txt
# large_movie_review_dataset\test\pos/2401_7.txt
# large_movie_review_dataset\test\pos/2405_9.txt
# large_movie_review_dataset\test\pos/2409_8.txt
# large_movie_review_dataset\test\pos/2411_8.txt
# large_movie_review_dataset\test\pos/2417_8.txt
# large_movie_review_dataset\test\pos/2422_7.txt
# large_movie_review_dataset\test\pos/2428_9.txt
# large_movie_review_dataset\test\pos/2436_10.txt
# large_movie_review_dataset\test\pos/2437_10.txt
# large_movie_review_dataset\test\pos/2465_7.txt
# large_movie_review_dataset\test\pos/2471_7.txt
# large_movie_review_dataset\test\pos/2473_10.txt
# large_movie_review_dataset\test\pos/2474_10.txt
# large_movie_review_dataset\test\pos/2477_10.txt
# large_movie_review_dataset\test\pos/2479_9.txt
# large_movie_review_dataset\test\pos/2488_9.txt
# large_movie_review_dataset\test\pos/2490_9.txt
# large_movie_review_dataset\test\pos/2491_10.txt
# large_movie_review_dataset\test\pos/2496_8.txt
# large_movie_review_dataset\test\pos/2504_7.txt
# large_movie_review_dataset\test\pos/2516_10.txt
# large_movie_review_dataset\test\pos/2517_7.txt
# large_movie_review_dataset\test\pos/2537_7.txt
# large_movie_review_dataset\test\pos/2541_10.txt
# large_movie_review_dataset\test\pos/2546_9.txt
# large_movie_review_dataset\test\pos/2547_7.txt
# large_movie_review_dataset\test\pos/2560_7.txt
# large_movie_review_dataset\test\pos/2562_10.txt
# large_movie_review_dataset\test\pos/2568_8.txt
# large_movie_review_dataset\test\pos/2573_10.txt
# ...
# large_movie_review_dataset\test\pos/4573_10.txt
# large_movie_review_dataset\test\pos/4576_10.txt
# large_movie_review_dataset\test\pos/4577_8.txt
# large_movie_review_dataset\test\pos/4580_10.txt
# large_movie_review_dataset\test\pos/4582_7.txt
# large_movie_review_dataset\test\pos/4583_8.txt
# large_movie_review_dataset\test\pos/4585_10.txt
# large_movie_review_dataset\test\pos/4586_10.txt
# large_movie_review_dataset\test\pos/4587_8.txt
# large_movie_review_dataset\test\pos/4588_9.txt
# large_movie_review_dataset\test\pos/4589_10.txt
# large_movie_review_dataset\test\pos/4590_10.txt
# large_movie_review_dataset\test\pos/4591_7.txt
# large_movie_review_dataset\test\pos/4594_8.txt
# large_movie_review_dataset\test\pos/4595_8.txt
# large_movie_review_dataset\test\pos/4596_7.txt
# large_movie_review_dataset\test\pos/4597_7.txt
# large_movie_review_dataset\test\pos/4598_10.txt
# large_movie_review_dataset\test\pos/4599_9.txt
# large_movie_review_dataset\test\pos/4600_8.txt
# large_movie_review_dataset\test\pos/4601_9.txt
# large_movie_review_dataset\test\pos/4602_8.txt
# large_movie_review_dataset\test\pos/4613_9.txt
# large_movie_review_dataset\test\pos/4617_10.txt
# large_movie_review_dataset\test\pos/4620_8.txt
# large_movie_review_dataset\test\pos/4622_8.txt
# large_movie_review_dataset\test\pos/4623_10.txt
# large_movie_review_dataset\test\pos/4635_10.txt
# large_movie_review_dataset\test\pos/4644_9.txt
# large_movie_review_dataset\test\pos/4647_10.txt
# large_movie_review_dataset\test\pos/4649_10.txt
# large_movie_review_dataset\test\pos/4653_10.txt
# large_movie_review_dataset\test\pos/4654_10.txt
# large_movie_review_dataset\test\pos/4656_10.txt
# large_movie_review_dataset\test\pos/4658_7.txt
# large_movie_review_dataset\test\pos/4659_10.txt
# large_movie_review_dataset\test\pos/4665_7.txt
# large_movie_review_dataset\test\pos/4667_7.txt
# large_movie_review_dataset\test\pos/4668_8.txt
# large_movie_review_dataset\test\pos/4669_8.txt
# large_movie_review_dataset\test\pos/4673_8.txt
# large_movie_review_dataset\test\pos/4675_8.txt
# large_movie_review_dataset\test\pos/4678_9.txt
# large_movie_review_dataset\test\pos/4679_8.txt
# large_movie_review_dataset\test\pos/467_9.txt
# large_movie_review_dataset\test\pos/4680_7.txt
# large_movie_review_dataset\test\pos/4684_9.txt
# large_movie_review_dataset\test\pos/4689_10.txt
# large_movie_review_dataset\test\pos/469_8.txt
# large_movie_review_dataset\test\pos/4706_10.txt
# large_movie_review_dataset\test\pos/4707_7.txt
# large_movie_review_dataset\test\pos/4708_10.txt
# large_movie_review_dataset\test\pos/4731_9.txt
# large_movie_review_dataset\test\pos/4732_10.txt
# large_movie_review_dataset\test\pos/4735_9.txt
# large_movie_review_dataset\test\pos/4740_9.txt
# large_movie_review_dataset\test\pos/4742_10.txt
# large_movie_review_dataset\test\pos/4744_9.txt
# large_movie_review_dataset\test\pos/4747_8.txt
# large_movie_review_dataset\test\pos/4754_8.txt
# large_movie_review_dataset\test\pos/4762_8.txt
# large_movie_review_dataset\test\pos/4763_7.txt
# large_movie_review_dataset\test\pos/4764_7.txt
# large_movie_review_dataset\test\pos/4767_9.txt
# large_movie_review_dataset\test\pos/476_9.txt
# large_movie_review_dataset\test\pos/4772_9.txt
# large_movie_review_dataset\test\pos/4786_9.txt
# large_movie_review_dataset\test\pos/4789_10.txt
# large_movie_review_dataset\test\pos/478_9.txt
# large_movie_review_dataset\test\pos/4794_9.txt
# large_movie_review_dataset\test\pos/4798_9.txt
# large_movie_review_dataset\test\pos/4800_10.txt
# large_movie_review_dataset\test\pos/4810_7.txt
# large_movie_review_dataset\test\pos/4813_8.txt
# large_movie_review_dataset\test\pos/4820_10.txt
# large_movie_review_dataset\test\pos/4822_8.txt
# large_movie_review_dataset\test\pos/4823_8.txt
# large_movie_review_dataset\test\pos/4824_8.txt
# large_movie_review_dataset\test\pos/4826_9.txt
# large_movie_review_dataset\test\pos/4827_7.txt
# large_movie_review_dataset\test\pos/4828_8.txt
# large_movie_review_dataset\test\pos/4829_7.txt
# large_movie_review_dataset\test\pos/4831_8.txt
# large_movie_review_dataset\test\pos/4836_10.txt
# large_movie_review_dataset\test\pos/4844_7.txt
# large_movie_review_dataset\test\pos/4856_8.txt
# large_movie_review_dataset\test\pos/4863_7.txt
# large_movie_review_dataset\test\pos/4864_8.txt
# large_movie_review_dataset\test\pos/4868_7.txt
# large_movie_review_dataset\test\pos/4869_8.txt
# large_movie_review_dataset\test\pos/486_10.txt
# large_movie_review_dataset\test\pos/4871_8.txt
# large_movie_review_dataset\test\pos/4873_8.txt
# large_movie_review_dataset\test\pos/4874_9.txt
# large_movie_review_dataset\test\pos/4875_10.txt
# large_movie_review_dataset\test\pos/4877_9.txt
# large_movie_review_dataset\test\pos/4878_9.txt
# large_movie_review_dataset\test\pos/4882_9.txt
# large_movie_review_dataset\test\pos/4883_7.txt
# large_movie_review_dataset\test\pos/4884_9.txt
# large_movie_review_dataset\test\pos/4887_10.txt
# large_movie_review_dataset\test\pos/490_8.txt
# large_movie_review_dataset\test\pos/4912_10.txt
# large_movie_review_dataset\test\pos/4918_8.txt
# large_movie_review_dataset\test\pos/4919_7.txt
# large_movie_review_dataset\test\pos/491_9.txt
# large_movie_review_dataset\test\pos/4923_9.txt
# large_movie_review_dataset\test\pos/4930_10.txt
# large_movie_review_dataset\test\pos/4946_8.txt
# large_movie_review_dataset\test\pos/494_10.txt
# large_movie_review_dataset\test\pos/4950_10.txt
# large_movie_review_dataset\test\pos/4953_7.txt
# large_movie_review_dataset\test\pos/4955_7.txt
# large_movie_review_dataset\test\pos/4956_9.txt
# large_movie_review_dataset\test\pos/4957_8.txt
# large_movie_review_dataset\test\pos/4958_7.txt
# large_movie_review_dataset\test\pos/4959_10.txt
# large_movie_review_dataset\test\pos/495_10.txt
# large_movie_review_dataset\test\pos/4970_9.txt
# large_movie_review_dataset\test\pos/4971_8.txt
# large_movie_review_dataset\test\pos/4978_9.txt
# large_movie_review_dataset\test\pos/497_9.txt
# large_movie_review_dataset\test\pos/4989_7.txt
# large_movie_review_dataset\test\pos/498_10.txt
# large_movie_review_dataset\test\pos/4990_7.txt
# large_movie_review_dataset\test\pos/4997_8.txt
# large_movie_review_dataset\test\pos/499_8.txt
# large_movie_review_dataset\test\pos/5001_8.txt
# large_movie_review_dataset\test\pos/5003_10.txt
# large_movie_review_dataset\test\pos/5005_8.txt
# large_movie_review_dataset\test\pos/5009_10.txt
# large_movie_review_dataset\test\pos/500_10.txt
# large_movie_review_dataset\test\pos/5010_10.txt
# large_movie_review_dataset\test\pos/5013_9.txt
# large_movie_review_dataset\test\pos/5016_8.txt
# large_movie_review_dataset\test\pos/5028_8.txt
# large_movie_review_dataset\test\pos/5029_7.txt
# large_movie_review_dataset\test\pos/5047_10.txt
# large_movie_review_dataset\test\pos/504_8.txt
# large_movie_review_dataset\test\pos/5056_7.txt
# large_movie_review_dataset\test\pos/5057_8.txt
# large_movie_review_dataset\test\pos/5059_10.txt
# large_movie_review_dataset\test\pos/5062_7.txt
# large_movie_review_dataset\test\pos/5069_8.txt
# large_movie_review_dataset\test\pos/506_8.txt
# large_movie_review_dataset\test\pos/5071_8.txt
# large_movie_review_dataset\test\pos/5072_9.txt
# large_movie_review_dataset\test\pos/5083_10.txt
# large_movie_review_dataset\test\pos/5085_8.txt
# large_movie_review_dataset\test\pos/508_7.txt
# large_movie_review_dataset\test\pos/509_7.txt
# large_movie_review_dataset\test\pos/510_7.txt
# large_movie_review_dataset\test\pos/5110_10.txt
# large_movie_review_dataset\test\pos/5111_7.txt
# large_movie_review_dataset\test\pos/5118_10.txt
# large_movie_review_dataset\test\pos/5123_10.txt
# large_movie_review_dataset\test\pos/5124_10.txt
# large_movie_review_dataset\test\pos/5127_10.txt
# large_movie_review_dataset\test\pos/5128_7.txt
# large_movie_review_dataset\test\pos/5129_9.txt
# large_movie_review_dataset\test\pos/5133_10.txt
# large_movie_review_dataset\test\pos/5134_9.txt
# large_movie_review_dataset\test\pos/5137_10.txt
# large_movie_review_dataset\test\pos/5140_8.txt
# large_movie_review_dataset\test\pos/5147_7.txt
# large_movie_review_dataset\test\pos/5152_10.txt
# large_movie_review_dataset\test\pos/515_9.txt
# large_movie_review_dataset\test\pos/5165_8.txt
# large_movie_review_dataset\test\pos/5166_10.txt
# large_movie_review_dataset\test\pos/516_9.txt
# large_movie_review_dataset\test\pos/5170_8.txt
# large_movie_review_dataset\test\pos/5177_8.txt
# large_movie_review_dataset\test\pos/5178_8.txt
# large_movie_review_dataset\test\pos/5179_10.txt
# large_movie_review_dataset\test\pos/5184_8.txt
# large_movie_review_dataset\test\pos/5187_8.txt
# large_movie_review_dataset\test\pos/5195_10.txt
# large_movie_review_dataset\test\pos/519_7.txt
# large_movie_review_dataset\test\pos/5201_8.txt
# large_movie_review_dataset\test\pos/5205_10.txt
# large_movie_review_dataset\test\pos/5211_10.txt
# large_movie_review_dataset\test\pos/521_7.txt
# large_movie_review_dataset\test\pos/5220_10.txt
# large_movie_review_dataset\test\pos/522_10.txt
# large_movie_review_dataset\test\pos/5253_9.txt
# large_movie_review_dataset\test\pos/5255_7.txt
# large_movie_review_dataset\test\pos/5270_10.txt
# large_movie_review_dataset\test\pos/5274_8.txt
# large_movie_review_dataset\test\pos/5276_8.txt
# large_movie_review_dataset\test\pos/5308_10.txt
# large_movie_review_dataset\test\pos/530_10.txt
# large_movie_review_dataset\test\pos/5311_9.txt
# large_movie_review_dataset\test\pos/5323_9.txt
# large_movie_review_dataset\test\pos/5328_10.txt
# large_movie_review_dataset\test\pos/532_8.txt
# large_movie_review_dataset\test\pos/5330_8.txt
# large_movie_review_dataset\test\pos/5332_8.txt
# large_movie_review_dataset\test\pos/5340_8.txt
# large_movie_review_dataset\test\pos/5345_10.txt
# large_movie_review_dataset\test\pos/5346_10.txt
# large_movie_review_dataset\test\pos/5352_10.txt
# large_movie_review_dataset\test\pos/5355_10.txt
# large_movie_review_dataset\test\pos/5356_7.txt
# large_movie_review_dataset\test\pos/5369_10.txt
# large_movie_review_dataset\test\pos/536_7.txt
# large_movie_review_dataset\test\pos/5371_7.txt
# large_movie_review_dataset\test\pos/5373_7.txt
# large_movie_review_dataset\test\pos/5380_8.txt
# large_movie_review_dataset\test\pos/5387_8.txt
# large_movie_review_dataset\test\pos/5388_8.txt
# large_movie_review_dataset\test\pos/5390_7.txt
# large_movie_review_dataset\test\pos/53_7.txt
# large_movie_review_dataset\test\pos/5402_7.txt
# large_movie_review_dataset\test\pos/540_8.txt
# large_movie_review_dataset\test\pos/5418_9.txt
# large_movie_review_dataset\test\pos/5433_7.txt
# large_movie_review_dataset\test\pos/5435_7.txt
# large_movie_review_dataset\test\pos/5437_8.txt
# large_movie_review_dataset\test\pos/5442_8.txt
# large_movie_review_dataset\test\pos/5446_7.txt
# large_movie_review_dataset\test\pos/5449_7.txt
# large_movie_review_dataset\test\pos/5451_8.txt
# large_movie_review_dataset\test\pos/5453_8.txt
# large_movie_review_dataset\test\pos/545_7.txt
# large_movie_review_dataset\test\pos/5462_8.txt
# large_movie_review_dataset\test\pos/5463_10.txt
# large_movie_review_dataset\test\pos/5502_10.txt
# large_movie_review_dataset\test\pos/5505_7.txt
# large_movie_review_dataset\test\pos/5506_9.txt
# large_movie_review_dataset\test\pos/5507_7.txt
# large_movie_review_dataset\test\pos/5508_7.txt
# large_movie_review_dataset\test\pos/5509_9.txt
# large_movie_review_dataset\test\pos/5510_9.txt
# large_movie_review_dataset\test\pos/5511_10.txt
# large_movie_review_dataset\test\pos/5515_10.txt
# large_movie_review_dataset\test\pos/5517_10.txt
# large_movie_review_dataset\test\pos/5520_10.txt
# large_movie_review_dataset\test\pos/5521_8.txt
# large_movie_review_dataset\test\pos/5523_8.txt
# large_movie_review_dataset\test\pos/5524_10.txt
# large_movie_review_dataset\test\pos/5525_7.txt
# large_movie_review_dataset\test\pos/5535_8.txt
# large_movie_review_dataset\test\pos/5539_7.txt
# large_movie_review_dataset\test\pos/5543_7.txt
# large_movie_review_dataset\test\pos/5548_9.txt
# large_movie_review_dataset\test\pos/5554_10.txt
# large_movie_review_dataset\test\pos/5558_10.txt
# large_movie_review_dataset\test\pos/5562_9.txt
# large_movie_review_dataset\test\pos/5564_10.txt
# large_movie_review_dataset\test\pos/5565_10.txt
# large_movie_review_dataset\test\pos/5572_7.txt
# large_movie_review_dataset\test\pos/5581_10.txt
# large_movie_review_dataset\test\pos/5588_10.txt
# large_movie_review_dataset\test\pos/5589_10.txt
# large_movie_review_dataset\test\pos/5598_8.txt
# large_movie_review_dataset\test\pos/5608_8.txt
# large_movie_review_dataset\test\pos/562_8.txt
# large_movie_review_dataset\test\pos/5633_8.txt
# large_movie_review_dataset\test\pos/5635_9.txt
# large_movie_review_dataset\test\pos/563_10.txt
# large_movie_review_dataset\test\pos/5647_10.txt
# large_movie_review_dataset\test\pos/564_9.txt
# large_movie_review_dataset\test\pos/5655_10.txt
# large_movie_review_dataset\test\pos/5658_9.txt
# large_movie_review_dataset\test\pos/5661_10.txt
# large_movie_review_dataset\test\pos/5671_8.txt
# large_movie_review_dataset\test\pos/5672_7.txt
# large_movie_review_dataset\test\pos/5673_8.txt
# large_movie_review_dataset\test\pos/5674_7.txt
# large_movie_review_dataset\test\pos/5675_9.txt
# large_movie_review_dataset\test\pos/5676_7.txt
# large_movie_review_dataset\test\pos/5678_10.txt
# large_movie_review_dataset\test\pos/5679_7.txt
# large_movie_review_dataset\test\pos/567_9.txt
# large_movie_review_dataset\test\pos/5680_7.txt
# large_movie_review_dataset\test\pos/5681_9.txt
# large_movie_review_dataset\test\pos/5682_10.txt
# large_movie_review_dataset\test\pos/5684_8.txt
# large_movie_review_dataset\test\pos/5686_8.txt
# large_movie_review_dataset\test\pos/5688_7.txt
# large_movie_review_dataset\test\pos/5689_8.txt
# large_movie_review_dataset\test\pos/568_9.txt
# large_movie_review_dataset\test\pos/5691_7.txt
# large_movie_review_dataset\test\pos/5692_8.txt
# large_movie_review_dataset\test\pos/5694_9.txt
# large_movie_review_dataset\test\pos/5700_9.txt
# large_movie_review_dataset\test\pos/570_9.txt
# large_movie_review_dataset\test\pos/5711_10.txt
# large_movie_review_dataset\test\pos/5716_10.txt
# large_movie_review_dataset\test\pos/5723_8.txt
# large_movie_review_dataset\test\pos/5725_10.txt
# large_movie_review_dataset\test\pos/5728_10.txt
# large_movie_review_dataset\test\pos/5732_10.txt
# large_movie_review_dataset\test\pos/5733_9.txt
# large_movie_review_dataset\test\pos/5734_10.txt
# large_movie_review_dataset\test\pos/5735_7.txt
# large_movie_review_dataset\test\pos/5738_7.txt
# large_movie_review_dataset\test\pos/5739_7.txt
# large_movie_review_dataset\test\pos/5740_10.txt
# large_movie_review_dataset\test\pos/5742_10.txt
# large_movie_review_dataset\test\pos/5743_10.txt
# large_movie_review_dataset\test\pos/5744_10.txt
# large_movie_review_dataset\test\pos/5745_7.txt
# large_movie_review_dataset\test\pos/5749_8.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-842379984305> in <module>()
# ----> 1 print nb.evaluate_classifier_accuracy(1.0)
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in evaluate_classifier_accuracy(self, alpha)
#     234                     content = doc.read()
#     235                     bow = self.tokenize_doc(content)
# --> 236                     if self.classify(bow, alpha) == label:
#     237                         correct += 1.0
#     238                     else:
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in classify(self, bow, alpha)
#     202         """
#     203         pos = self.unnormalized_log_posterior(bow, POS_LABEL, alpha)
# --> 204         neg = self.unnormalized_log_posterior(bow, NEG_LABEL, alpha)
#     205         return POS_LABEL if pos > neg else NEG_LABEL
#     206
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in unnormalized_log_posterior(self, bow, label, alpha)
#     190         bow - a bag of words (i.e., a tokenized document)
#     191         """
# --> 192         return self.log_likelihood(bow, label, alpha) + self.log_prior(label)
#     193
#     194     def classify(self, bow, alpha):
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in log_likelihood(self, bow, label, alpha)
#     173         alpha - float; pseudocount parameter
#     174         """
# --> 175         return sum([math.log10(self.p_word_given_label_and_pseudocount(word, label, alpha)) for word in bow])
#     176
#     177     def log_prior(self, label):
#
# KeyboardInterrupt:

# %% [markdown]
# **Question 2.10 (5 pts)**
#
# Try evaluating your model again with a pseudocount parameter of 500.

# %%
print nb.evaluate_classifier_accuracy(500.0)
# Out:
# 74.26

# %% [markdown]
# Does the accuracy go up or down when the pseudo count parameter is raised to 500? Why do you think this is?
#
# Answer in one or two sentences here.
#
# The accurracy goes down because by adding 500 to the count of every word, the data is skewed so that rare words are more impactful and common words are less impactful, reducing the effect that actual positive words have on the classifier, as well as increasing the effect that random unrelated words have on the classifier.

# %% [markdown]
# **Question 2.11 (5 pts)**
#
# Our trained model can be queried to do exploratory data analysis. We
# saw that the top 10 most common words for each class were not very
# discriminative. Often times, a more descriminative statistic is a
# word's likelihood ratio. A word's likelihood ratio is defined as
#
# $LR(w)=\frac{P(w|y=\mathrm{pos})}{P(w|y=\mathrm{neg})}$
#
# A word with $LR=5$ is five times more likely to appear in a positive
# review than it is in a negative review; a word with $LR=0.33$ is one
# third as likely to appear in a positive review than a negative review

# %%
# Implement the nb.likelihod_ratio function and use it to investigate the likelihood ratio of "fantastic" and "boring"
print "LIKEHOOD RATIO OF 'fantastic':", nb.likelihood_ratio('fantastic', 1.0)
print "LIKEHOOD RATIO OF 'boring':", nb.likelihood_ratio('boring', 1.0)
print "LIKEHOOD RATIO OF 'the':", nb.likelihood_ratio('the', 1.0)
print "LIKEHOOD RATIO OF 'to':", nb.likelihood_ratio('to', 1.0)
# Out:
# LIKEHOOD RATIO OF 'fantastic': 4.089221761
# LIKEHOOD RATIO OF 'boring': 0.215301730398
# LIKEHOOD RATIO OF 'the': 1.03406598139
# LIKEHOOD RATIO OF 'to': 0.943417768851

# %% [markdown]
# Does it make sense that $LR$('fantastic') $>$ $LR$('to')?
#
# Answer in one or two sentences here.
#
# Yes; "fantastic" is a word with a positive connotation and is likely to occur in positive reviews, with a LR > 1. On the other hand, "to" is a word with no context and is likely to occur in both types of reviews, with a LR approximating 1.

# %% [markdown]
# ** Question 2.12 (15 pts)**
#
# Find a review that your classifier got wrong.

# %%
# in this cell, print out a review that your classifier got wrong. Print out the text of the review along with the label

"""
filename = large_movie_review_dataset\test\pos\2_7.txt
text = My yardstick for measuring a movie's watch-ability is if I get squirmy. If I start shifting positions and noticing my butt is sore, the film is too long. This movie did not even come close to being boring. Predictable in some parts sure, but never boring.<br /><br />All of the other military branches have had love notes written about them and seen their recruitment levels go up, why not the Coast Guard too? They are definitely under-appreciated, until the day your boat sinks that is.<br /><br />The movie was very enjoyable and fun. Kevin Costner is perfect as the aging macho man who doesn't know when to quit. However, I was most impressed by Ashton Kutcher's performance. I have never liked him, never watched any of his TV shows and always considered him an immature ... well, punk. In this film, he does a great job! He is well on his way to having leading-man status. I think the film we were shown must have been an advance rough cut or something, because about 2/3 of the way in, the film stock turned very grainy, the sound level dropped and microphones were seen dropping down all over the place. Also at the viewing were representatives from the movie, looking for audience feedback - particularly on the parts of the film we didn't like.<br /><br />*****POSSIBLE SPOILER: The feedback I gave concerned a a couple of lines in the beginning. Kevin Costner comes home to see his wife, Sela Ward, packing her stuff up and moving out. He says, "Maybe I should be the one to move out." And she replies, "No, you don't know where anything is in this house; I should be the one to go." This doesn't make sense: If she knows the layout so well, Costner is right, he *should* be the one to leave.
"""
with open(r'large_movie_review_dataset\test\pos\2_7.txt', 'r') as txt:
    content = txt.read()
print content
print ''
print 'Classification: ' + nb.classify(tokenize_doc(content), 1)
# Out:
# My yardstick for measuring a movie's watch-ability is if I get squirmy. If I start shifting positions and noticing my butt is sore, the film is too long. This movie did not even come close to being boring. Predictable in some parts sure, but never boring.<br /><br />All of the other military branches have had love notes written about them and seen their recruitment levels go up, why not the Coast Guard too? They are definitely under-appreciated, until the day your boat sinks that is.<br /><br />The movie was very enjoyable and fun. Kevin Costner is perfect as the aging macho man who doesn't know when to quit. However, I was most impressed by Ashton Kutcher's performance. I have never liked him, never watched any of his TV shows and always considered him an immature ... well, punk. In this film, he does a great job! He is well on his way to having leading-man status. I think the film we were shown must have been an advance rough cut or something, because about 2/3 of the way in, the film stock turned very grainy, the sound level dropped and microphones were seen dropping down all over the place. Also at the viewing were representatives from the movie, looking for audience feedback - particularly on the parts of the film we didn't like.<br /><br />*****POSSIBLE SPOILER: The feedback I gave concerned a a couple of lines in the beginning. Kevin Costner comes home to see his wife, Sela Ward, packing her stuff up and moving out. He says, "Maybe I should be the one to move out." And she replies, "No, you don't know where anything is in this house; I should be the one to go." This doesn't make sense: If she knows the layout so well, Costner is right, he *should* be the one to leave.
#
# Classification: neg

# %% [markdown]
# What are two reasons your system might have misclassified this example? What improvements could you make that may help your system classify this example correctly?

# %% [markdown]
# Fill out reason nubmer 1 here | Fill out a possible improvement here
#
# Classifier doesn't deal with negation because it only looks at unigrams. It sees words like "not" and "boring" but not the bigram "not boring" and incorrectly inteprets the words as negative in the context. A way to improve the classifier would be to classify on bigrams.
#
#
# Fill out reason nubmer 2 here | Fill out a possible improvement here
#
# Classifier does not differentiate between multiple meanings of words. "Concerned" can mean both "worried" or "about." The classifier likely assigned "concerned" a negative connotation while the actual contex, "feedback I gave concerned" is fairly neutral. A way to improve the classifier would be to use a lexicon to impart weightings to words. Words that have only one meaning are weighted heavily, while words with many meanings are worth less.

# %% [markdown]
# **Extra credit (up to 10 points) **
#
# If you don't want to do the extra credit, you can stop here! Otherwise... keep reading...
#
# In this assignment, we use whitespace tokenization to create a bag-of-unigrams representation for the movie reviews. It is possible to improve this represetation to improve your classifier's performance. Use your own code or an external library such as nltk to perform tokenization, text normalization, word filtering, etc. Fill out your work in `def tokenize_doc_and_more` (below) and then show improvement by running the following.
#
# `nb = NaiveBayes(PATH_TO_DATA, tokenizer=tokenize_doc_and_more)
# nb.train_model()
# nb.evaluate_classifier_accuracy(1.0)
# `
#
# Roughly speaking, the larger performance improvement, the more extra credit. However, doing a good job investigating, explaining and justifying your work with small experiments and comments is also extremely important. Make sure to describe what you did and analyze why your method works. Use this ipython notebook to show your work.

# %%
def tokenize_doc_and_more(doc):
    """
    Return some representation of a document.
    At a minimum, you need to perform tokenization, the rest is up to you.
    """
    # Implement me!
    bow = defaultdict(float)
    
    # your code goes here
    
    return dict[bow]

# %%
nb = NaiveBayes(PATH_TO_DATA, tokenizer=tokenize_doc_and_more)
nb.train_model()
nb.evaluate_classifier_accuracy(1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-018f5a8cab3f> in <module>()
#       1 nb = NaiveBayes(PATH_TO_DATA, tokenizer=tokenize_doc_and_more)
# ----> 2 nb.train_model()
#       3 nb.evaluate_classifier_accuracy(1.0)
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in train_model(self)
#      90                 with open(os.path.join(p,f),'r') as doc:
#      91                     content = doc.read()
# ---> 92                     self.tokenize_and_update_model(content, label)
#      93         self.report_statistics_after_training()
#      94
#
# C:\Users\Richard\Documents\GitHub\cs585\hw01\hw_1.py in tokenize_and_update_model(self, doc, label)
#     137         """
#     138
# --> 139         bow = self.tokenize_doc(doc)
#     140         self.update_model(bow, label)
#     141
#
# <ipython-input-78-b7697cebf68d> in tokenize_doc_and_more(doc)
#      14     bigrams.append(finder.nbest(bigram_measures.pmi, 500))
#      15     for bigram in bigrams:
# ---> 16         bob[bigram] += 1.0
#      17
#      18     # your code goes here
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Use cells at the bottom of this notebook to explain what you did in `better_tokenize_doc`. Include any experiments or explanations that you used to decide what goes in your function.

# %%
# Your experiments and explanations go here
